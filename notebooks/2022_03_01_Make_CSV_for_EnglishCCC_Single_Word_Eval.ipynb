# %%
import pandas as pd
import os 
from pathlib import Path
import numpy as np
# %matplotlib inline 
import matplotlib.pyplot as plt 
from matplotlib import cm

# %%
ccc_path = '/om2/user/imgriff/projects/cocktail_party/datasets/EnglishCCC_v1.2'

# %%
ccc_df = pd.read_csv(Path(ccc_path, "confusionCorpus_v1.2.csv"))

# %%
from IPython.display import Audio

# %%
path_to_ECCC = '/om2/user/imgriff/projects/cocktail_party/datasets/EnglishCCC_v1.2/confusionWavs/'

# %%
make_path = lambda ID: Path(path_to_ECCC, f"T_{ID}.wav").as_posix()

ccc_df['wav_path'] = ccc_df['ID'].apply(make_path)
# Out:
# <ipython-input-11-643ebc0a64f3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wanted_df['wav_path'] = wanted_df['ID'].apply(make_path)

# %%
ccc_df.head(10)
# Out:
#      ID  Length Masker   Onset    SNR Speaker    Target  \
# 0  3784   11520    SSN  104656 -6.982      s3   jointly
# 1  3786    9172    SSN  455143 -6.173      s3     buyer
# 2  3787   13280    SSN  658770 -6.200      s3     sleek
# 3  3791   14898    SSN  826266 -5.132      s3  perverse
# 4  3804   11876    SSN  496159 -5.623      s3   because
# 5  3805   12960    SSN  102704 -6.534      s3    remote
# 6  3848   10818   BAB4  521819 -2.165      s3    barber
# 7  3884    9440   BMN3  281850 -3.348      s2  childish
# 8  3891   11680   BMN3  787862 -7.670      s2    radius
# 9  3892   13280   BMN3  856391 -7.311      s2    stance
#
#                                                  Raw  \
# 0  drink|drink|drink|drinking|dream|jointly|join|...
# 1  fire|buyer|fire|fire|pie|fire|fire|quiet|fire|...
# 2  sleek|sleep|sleep|sleek|sleep|sleek|sleep|slee...
# 3  perverse|averse|traverse|reverse|reverse|perve...
# 4  curse|because|coat|coast|reverse|coast|coast|c...
# ...

# %%
Audio(ccc_df['wav_path'][4])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wanted_df = ccc_df[['ID', 'Target']]
wanted_df['wav_path'] = wanted_df['ID'].apply(make_path)
# Out:
# <ipython-input-13-7085ed2a2670>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wanted_df['wav_path'] = wanted_df['ID'].apply(make_path)

# %%
wanted_df
# Out:
#          ID     Target                                           wav_path
# 0      3784    jointly  /om2/user/imgriff/projects/cocktail_party/data...
# 1      3786      buyer  /om2/user/imgriff/projects/cocktail_party/data...
# 2      3787      sleek  /om2/user/imgriff/projects/cocktail_party/data...
# 3      3791   perverse  /om2/user/imgriff/projects/cocktail_party/data...
# 4      3804    because  /om2/user/imgriff/projects/cocktail_party/data...
# ...     ...        ...                                                ...
# 3202  43714       dose  /om2/user/imgriff/projects/cocktail_party/data...
# 3203  43715  fifteenth  /om2/user/imgriff/projects/cocktail_party/data...
# 3204  43726   presence  /om2/user/imgriff/projects/cocktail_party/data...
# 3205  43788     output  /om2/user/imgriff/projects/cocktail_party/data...
# 3206  43873      shelf  /om2/user/imgriff/projects/cocktail_party/data...
#
# [3207 rows x 3 columns]

# %%
wanted_df.wav_path[0], wanted_df.Target[0],
# Out:
# ('/om2/user/imgriff/projects/cocktail_party/datasets/EnglishCCC_v1.2/confusionWavs/T_3784.wav',
#  'jointly')

# %%
out_df = wanted_df[['wav_path', 'Target']]

# %%
out_df['word'] = out_df['Target'].str.upper()

# %%
out_df = out_df[['wav_path', 'word']]

# %%
out_df
# Out:
#                                                wav_path       word
# 0     /om2/user/imgriff/projects/cocktail_party/data...    JOINTLY
# 1     /om2/user/imgriff/projects/cocktail_party/data...      BUYER
# 2     /om2/user/imgriff/projects/cocktail_party/data...      SLEEK
# 3     /om2/user/imgriff/projects/cocktail_party/data...   PERVERSE
# 4     /om2/user/imgriff/projects/cocktail_party/data...    BECAUSE
# ...                                                 ...        ...
# 3202  /om2/user/imgriff/projects/cocktail_party/data...       DOSE
# 3203  /om2/user/imgriff/projects/cocktail_party/data...  FIFTEENTH
# 3204  /om2/user/imgriff/projects/cocktail_party/data...   PRESENCE
# 3205  /om2/user/imgriff/projects/cocktail_party/data...     OUTPUT
# 3206  /om2/user/imgriff/projects/cocktail_party/data...      SHELF
#
# [3207 rows x 2 columns]

# %%
out_path = Path(ccc_path, 'EnglishConsistentConfusionCorpus_words.csv')
# out_df.to_csv(out_path)
