# %%
import pandas as pd
import numpy as np 
from pathlib import Path

# %%
# harmonic_path_dfs = list(Path('/om2/user/imgriff/datasets/timit/harmonic_timit/').glob("*subset*.pdpkl"))
harmonic_path_dfs = list(Path('/om2/user/imgriff/datasets/timit/harmonic_timit_using_jitter_fn/').glob("*subset*.pdpkl"))

all_harmonic = pd.concat([pd.read_pickle(pd_file) for pd_file in harmonic_path_dfs],
                          axis=0, ignore_index=True)

# %%
all_harmonic.shape
# Out:
# (902, 26)

# %%
out_name = '/om2/user/imgriff/datasets/timit/harmonic_timit/all_targets_harmonic_single_distractor_0dB_SNR_jitter_fn_render.pdpkl'

all_harmonic.to_pickle(out_name)
