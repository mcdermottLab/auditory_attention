# %%
import librosa 
from pathlib import Path
import numpy as np 
import soundfile as sf
from scipy.io import wavfile
from IPython.display import Audio

# %%
path = '/mindhive/mcdermott/www/mturk_stimuli/imgriff/single_word_rec/pilot'

# use resampled words for this: 
clean_paths = Path(path, 'giga_200_words').glob('*.wav')
low_path = Path(path, 'giga_200_-5_snr').glob('*.wav')
high_path = Path(path, 'giga_200_0_snr').glob('*.wav')

# %% [markdown]
# ## Examples

# %%
wav, sr = librosa.load(next(clean_paths),sr=16000)
Audio(wav, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wav, sr = librosa.load(next(high_path),sr=16000)
Audio(wav, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wav, sr = librosa.load(next(low_path),sr=16000)
Audio(wav, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
