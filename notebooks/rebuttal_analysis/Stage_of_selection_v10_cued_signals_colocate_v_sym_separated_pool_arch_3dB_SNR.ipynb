# %%
import numpy as np 
import pickle 
import h5py
from scipy import stats
from tqdm.auto import tqdm
from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats import pearsonr
import pandas as pd
from pathlib import Path
import re


# %matplotlib inline 
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import src.util_analysis as util_analysis

# %%
# So that we can edit the text in illustrator
matplotlib.rcParams.update({'font.size': 10})
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
matplotlib.rcParams['svg.fonttype'] = 'none'

# %%
analysis_dir = Path(f"/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/")
all_models = list(analysis_dir.glob("*v10*"))
models_to_run = []

for path in all_models:
    if not path.is_dir():
        continue

    if 'control' in path.stem:
        continue

    models_to_run.append(path)


model_name_dict = {path.stem: util_analysis.get_model_name(path.stem) for path in models_to_run}


def sort_layers(layers):
    # Separate layers into categories
    coch_layers = ['cochleagram', 'norm_coch_rep']
    fc_layers = ['attnfc', 'relufc']
    n_blocks = len([layer for layer in layers if ('relu' in layer and 'fc' not in layer)])

    block_order = []
    for block_ix in range(n_blocks):
        block_order.append(f'attn{block_ix}')
        block_order.append(f'conv{block_ix}_ln')
        block_order.append(f'conv{block_ix}_relu')
        block_order.append(f'hann_pool_{block_ix}')

    # Combine all categories in the desired order
    return coch_layers + block_order + fc_layers


import scipy
vec_pearsonr = np.vectorize(scipy.stats.pearsonr,
                signature='(n),(n)->(),()')

# %%
analysis_dir / 'word_task_v10_main_feature_gain_config'
# Out:
# PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_main_feature_gain_config')

# %%
models_to_run
# Out:
# [PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_8_rand_weights'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_10'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_7'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_6'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_8'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_4'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_7_rand_weights'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_2_rand_weights'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_12_rand_weights'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_main_feature_gain_config_latest_ckpt'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_1'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_6_rand_weights'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_main_feature_gain_config_latest_ckpt_rand_weights'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_early_only_v10'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_4_rand_weights'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_9'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_12'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_9_rand_weights'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_10_rand_weights'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_late_only_v10_rand_weights'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_early_only_v10_rand_weights'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_2'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_late_only_v10'),
#  PosixPath('/om/scratch/Fri/imgriff/binaural_unit_activation_analysis_symmetric_distractor/word_task_v10_4MGB_ln_first_arch_1_rand_weights')]

# %%
## hide future warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

h5_fn = analysis_dir/'word_task_v10_main_feature_gain_config_latest_ckpt/word_task_v10_main_feature_gain_config_latest_ckpt_model_activations_0dB_cue_single_source_as_fn_of_sep_symmetric_distractor.h5'


# for path in paths:
distractor_conditions = ['same_sex_talker', 'diff_sex_talker',  'natural_scene']

# just look at 0,0 co-located examples 
# wanted_rows = np.where(np.all(target_locs == [0,0], axis=1))[0]
dfs = []

for model_dir in models_to_run:
    h5_fn = model_dir / f"{model_dir.stem}_model_activations_3dB_cue_single_source_as_fn_of_sep_symmetric_distractor.h5"

    try:
        with h5py.File(h5_fn, 'r', swmr=True) as acts:
            ## Get keys with corr in them 
            all_act_keys = list(acts.keys())
            layer_names = set([l.split('_target')[0].replace('_cued', '') for l in acts.keys() if 'target' in l and not  any([str_part in l for str_part in ['_f0', '_loc', '_word']])]) # set to remove duplicates 
            for layer in layer_names:
                data_dict = {}
                fg_corr_key = f"{layer}_cued_target_mixture_corr"
                bg_corr_key = f"{layer}_cued_symmetric_distractor_mixture_corr"  
                if layer == 'cochleagram': 
                    fg_corr_key = "cochleagram_target_mixture_corr"
                    bg_corr_key = "cochleagram_dist_mixture_corr"

                data_dict['fg_corrs'] = acts[fg_corr_key][:,0]
                data_dict['bg_corrs'] = acts[bg_corr_key][:,0]
                data_dict['target_azim'],  data_dict['target_elev'] = zip(*acts['target_loc'][:])
                data_dict['dist_l_azim'], data_dict['dist_l_elev'] = zip(*acts['distractor_l_loc'][:])
                # data_dict['dist_r_azim'], data_dict['dist_r_elev'] = zip(*acts['distractor_r_loc'][:])
                N_examples = len(data_dict['fg_corrs'])

                data_dict['layer'] = [layer] * N_examples

                df = pd.DataFrame(data_dict)
                df['model_name'] = model_name_dict[h5_fn.parent.name]
                df['group'] = 'random weights' if 'rand' in h5_fn.parent.name else 'feature-gain'
                dfs.append(df)
    except Exception as e:
        print(f"Error with {h5_fn}")
        print(e)
        # raise

def get_spatial_cond_str(cond_str):
    return f'+/- {int(cond_str)}° sep.'

act_results  = pd.concat(dfs, ignore_index=True)
act_results['spatial_cond'] = act_results['dist_l_azim'].apply( get_spatial_cond_str)
act_results['layer'] = act_results['layer'].str.replace('_block_', '')

act_results['log_corr_ratio'] = np.log(np.sqrt(act_results['fg_corrs']**2 / act_results['bg_corrs']**2))

act_corrs = pd.melt(act_results[[col for col in act_results.columns if 'cos' not in col]], id_vars =['layer', 'group', 'model_name', 'spatial_cond'], value_vars=['fg_corrs', 'bg_corrs'], var_name='Stream',
                            value_name="Pearson's r")


act_corrs['Stream'].replace('fg_corrs','corr(target$_i$, mixture$_i$)',inplace=True)
act_corrs['Stream'].replace('bg_corrs','corr(distractor$_i$, mixture$_i$)',inplace=True)

# act_corrs['distractor_condition'].replace('same_sex_talker','Same sex',inplace=True)
# act_corrs['distractor_condition'].replace('diff_sex_talker','Different sex',inplace=True)
# act_corrs['distractor_condition'].replace('natural_scene','Natural scene',inplace=True)

# %%
act_corrs.group.value_counts()
# Out:
# group
# random weights    366000
# feature-gain      366000
# Name: count, dtype: int64

# %%
import re
# Get layer order per model. Will have from [cochleagram, norm_coch_rep, ..., attnfc, relufc]
layer_order_dict = {}

def get_int(val):
    return int(re.search(r'\d+', val).group())

for model in act_results['model_name'].unique():
    layers = act_results.loc[act_results['model_name'] == model, 'layer'].unique()
    sorted_layers = sort_layers(layers)
    for layer in sorted_layers:
        if (model == "Computed-gain model" or 'Backbone' in model) and 'attn' in layer:
            sorted_layers.remove(layer)
        if model == 'Late-only':
            if 'attn' in layer and layer != 'attnfc':
                sorted_layers.remove(layer)
        elif model == 'Early-only':
            if 'attn' in layer:
                layer_int = len(layers) if 'fc' in layer else get_int(layer)
                if layer_int > 0:
                    sorted_layers.remove(layer)
    layer_order_dict[model] = sorted_layers

# %% [markdown]
# # Main figure

# %%
df_for_agg = act_corrs[act_corrs.model_name.str.contains('main|alt')].copy()
df_for_agg = df_for_agg.groupby(['model_name', 'group', 'layer', 'spatial_cond', 'Stream']).agg({'Pearson\'s r': ['mean', 'sem']}).reset_index()
df_for_agg.columns = ['model_name', 'group', 'layer', 'spatial_cond', 'Stream', 'r', 'r_sem']
df_for_agg = df_for_agg[df_for_agg.layer.str.contains('cochlea|relu')].reset_index(drop=True)

# %%
df_for_agg.Stream = df_for_agg['Stream'].str.replace('r_tgt_mixture', 'corr(target$_i$, mixture$_i$)')
df_for_agg.Stream = df_for_agg['Stream'].str.replace('r_dist_mixture', 'corr(distractor$_i$, mixture$_i$)')
# df_for_agg

# %%
## Plot summary_results df 
sns.set_style('ticks')
# order = np.sort(results.layer.unique())

# act_corrs

df_for_agg.Stream.rename({'r_tgt_mixture': 'corr(target$_i$, mixture$_i$)', 'r_dist_mixture': 'corr(distractor$_i$, mixture$_i$)'}, inplace=True)

hue_order = ['corr(target$_i$, mixture$_i$)', 'corr(distractor$_i$, mixture$_i$)'] 
# make palette for models in husl 
palette = sns.color_palette("husl", 2)
# make palette dict 
palette_dict = {'corr(target$_i$, mixture$_i$)': palette[1],
                'corr(distractor$_i$, mixture$_i$)': palette[0],}

# add line style dict 
line_style_dict = {'corr(target$_i$, mixture$_i$)': '-',
                   'corr(distractor$_i$, mixture$_i$)': '-'}  
 
# col_wrap = 6

models = df_for_agg.model_name.unique()
n_models = len(models)


tgt_locs = [
            '+/- 0° sep.',
            '+/- 5° sep.',
            '+/- 45° sep.',
            ]

n_cols = len(tgt_locs) # trained + rand 
n_rows = 2 # int(np.ceil(n_models / n_cols))
panel_height = 3
fontsize=12
fig, axs = plt.subplots(n_rows, n_cols, figsize=(n_cols* panel_height , n_rows*panel_height), sharex=False, sharey=False)
# axs = axs.flatten()


for i, model in enumerate(models):
    row_ix = 1 if 'rand' in model else 0 
    model_df = df_for_agg[df_for_agg['model_name'] == model]
    for axs_ix, loc in enumerate(tgt_locs):
        model_for_panel = model_df[model_df['spatial_cond'] == loc].set_index('layer')
        layers = [l for l in layer_order_dict[model] if 'cochlea' in l or 'relu' in l]
        try:
            model_for_panel = model_for_panel.loc[layers].reset_index()
            x_axis = np.linspace(0, 1, len(layers))
            for stream in model_for_panel.Stream.unique():
                stream_data = model_for_panel[model_for_panel['Stream'] == stream]
                axs[row_ix, axs_ix].errorbar(x_axis, stream_data['r'], yerr=stream_data['r_sem'], label=stream if axs_ix == 0 else None, alpha=0.1, color=palette_dict[stream])
                axs[row_ix, axs_ix].fill_between(x_axis, stream_data['r'] - stream_data['r_sem'], stream_data['r'] + stream_data['r_sem'], alpha=0.5, color=palette_dict[stream])
        except Exception as e:
            print(f"Error with {model}")
            print(e)
            continue
        if i == 0 :
            axs[0, axs_ix].set_title(f"Feature-gain Model\n{loc}", size=fontsize, y=1.05)
            axs[1, axs_ix].set_title("Feature-gain Models\nRandom weights", size=fontsize, y=1.05)
# p.axes[0,0].xaxis.labelpad = -0.25

# axs[1].legend().remove() # (loc='center left', bbox_to_anchor=(1, 0.5), title='Stream', frameon=False, title_fontsize=fontsize)
# make panels square 
# for ax in axs:
for ax in axs.ravel():
    ax.set_aspect('auto')
    ax.set_box_aspect(1)
    ax.set_ylim(0, 1)
    # ax.set_xlim(-0.5, len(layers) - 0.5)
    ax.set_xticks([0,1])
    ax.set_xticklabels(labels=['cochlea', 'relufc'], rotation=0, size=fontsize, )
    ax.set(ylim=(0,1))
    ax.set_xlabel("Network Layer", size=fontsize)
    ax.set_ylabel("Pearson's r", size=fontsize)
    # remove spines
    for spine in ax.spines.values():
        spine.set_linewidth(1.5)
    ax.tick_params(axis='both', which='major', length=5, width=1.5)


# remove legend, and instead plot as colored text 
# axs.legend().remove()
top_y_loc = .175
x_coord = -0.025
# axs[0].text(x_coord, top_y_loc, 'corr(target$_i$, mixture$_i$)', ha='left', va='center', fontsize=fontsize-2, color=palette_dict['corr(target$_i$, mixture$_i$)'])
# axs[0].text(x_coord, top_y_loc - .1, 'corr(distractor$_i$, mixture$_i$)', ha='left', va='center', fontsize=fontsize-2, color=palette_dict['corr(distractor$_i$, mixture$_i$)'])

sns.despine()

# adjust spacing
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.suptitle('Stage of selection with target at 3dB SNR', y=1)
# increase size of ticks
# increase size of ticks

# plt.savefig(fig_out_dir / "figure_5_all_arch_traces.pdf", transparent=True, bbox_inches='tight')

# plt.tight_layout()
# Out:
# Text(0.5, 1, 'Stage of selection with target at 3dB SNR')

# %%
## Plot summary_results df \
df_for_agg = act_corrs[act_corrs.model_name.str.contains('main|alt')].copy()
## Plot summary_results df \
df_for_agg = df_for_agg.groupby(['model_name',  'group', 'layer', 'spatial_cond', 'Stream']).agg({'Pearson\'s r': ['mean', 'sem']}).reset_index()
df_for_agg.columns = ['model_name',  'group', 'layer', 'spatial_cond', 'Stream', 'r', 'r_sem']
df_for_agg = df_for_agg[df_for_agg.layer.str.contains('cochlea|relu')].reset_index(drop=True)

sns.set_style('ticks')
# order = np.sort(results.layer.unique())

# act_corrs

df_for_agg.Stream.rename({'r_tgt_mixture': 'corr(target$_i$, mixture$_i$)', 'r_dist_mixture': 'corr(distractor$_i$, mixture$_i$)'}, inplace=True)

hue_order = ['corr(target$_i$, mixture$_i$)', 'corr(distractor$_i$, mixture$_i$)'] 
# make palette for models in husl 
palette = sns.color_palette("husl", 2)
# make palette dict 
palette_dict = {'corr(target$_i$, mixture$_i$)': palette[1],
                'corr(distractor$_i$, mixture$_i$)': palette[0],}



# add line style dict 
line_style_dict = {'Same sex': '-',
                   'Different sex': '--',
                   'Natural scene': ':'}  
 
# col_wrap = 6

all_models = act_results['model_name'].unique()
n_models = len(all_models)


tgt_locs = [
            '+/- 0° sep.',
            '+/- 5° sep.',
            '+/- 45° sep.',
            ]
n_cols = len(tgt_locs) # trained + rand 
n_rows = 1 # int(np.ceil(n_models / n_cols))
panel_height = 3
fontsize=12
fig, axs = plt.subplots(n_rows, n_cols, figsize=(n_cols* panel_height , n_rows*panel_height), sharex=False, sharey=False)
# axs = axs.flatten()


for axs_ix, loc in enumerate(tgt_locs):
    model_for_panel = df_for_agg[df_for_agg['spatial_cond'] == loc].set_index('layer')
    layers = [l for l in layer_order_dict[model] if 'cochlea' in l or 'relu' in l]
    # try:
    model_for_panel = model_for_panel.loc[layers].reset_index()
    # x_axis = np.linspace(0, 1, len(layers))
    x_axis = np.arange(len(layers))
    for stream in model_for_panel.Stream.unique():
        # for distractor_condition in model_for_panel.distractor_condition.unique():
        stream_data = model_for_panel[(model_for_panel['Stream'] == stream)]
        # print(stream)
        axs[axs_ix].fill_between(x_axis, stream_data['r'] - stream_data['r_sem'], stream_data['r'] + stream_data['r_sem'], alpha=0.5, color=palette_dict[stream])
        axs[axs_ix].errorbar(x_axis, stream_data['r'], yerr=stream_data['r_sem'], label=f"{stream}" if axs_ix == 0 else None, color=palette_dict[stream])


    axs[axs_ix].set_title(f"Feature-gain Model\n{loc}", size=fontsize, y=1.05)
# axs[1].set_title("Feature-gain Models\nRandom weights", size=fontsize, y=1.05)
# p.axes[0,0].xaxis.labelpad = -0.25

# axs[1].legend().remove() # (loc='center left', bbox_to_anchor=(1, 0.5), title='Stream', frameon=False, title_fontsize=fontsize)
# make panels square 
for ax in axs:
    ax.set_aspect('auto')
    ax.set_box_aspect(1)
    ax.set_ylim(0, 1)
    # ax.set_xlim(-0.5, len(layers) - 0.5)
    # ax.set_xticks([0,1])
    # ax.set_xticklabels(labels=['cochlea', 'relufc'], rotation=0, size=fontsize, )
    ax.set_xticks(x_axis)
    ax.set_xticklabels(labels=layers, rotation=90, size=fontsize-2)
    ax.set(ylim=(0,1))
    ax.set_xlabel("Network Layer", size=fontsize)
    ax.set_ylabel("Pearson's r", size=fontsize)
    # remove spines
    for spine in ax.spines.values():
        spine.set_linewidth(1.5)
    ax.tick_params(axis='both', which='major', length=5, width=1.5)

axs[0].legend(bbox_to_anchor=(-0.5, 1))

# remove legend, and instead plot as colored text 
# top_y_loc = .175
# x_coord = -0.025
# axs[0].text(x_coord, top_y_loc, 'corr(target$_i$, mixture$_i$)', ha='left', va='center', fontsize=fontsize-2, color=palette_dict['corr(target$_i$, mixture$_i$)'])
# axs[0].text(x_coord, top_y_loc - .1, 'corr(distractor$_i$, mixture$_i$)', ha='left', va='center', fontsize=fontsize-2, color=palette_dict['corr(distractor$_i$, mixture$_i$)'])

sns.despine()

# adjust spacing
plt.subplots_adjust(wspace=0.3, hspace=0.3)
# increase size of ticks
# increase size of ticks

# plt.savefig(fig_out_dir / "figure_5_all_arch_traces.pdf", transparent=True, bbox_inches='tight')

# plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 59
#      57     stream_data = model_for_panel[(model_for_panel['Stream'] == stream)]
#      58     # print(stream)
# ---> 59     axs[axs_ix].fill_between(x_axis, stream_data['r'] - stream_data['r_sem'], stream_data['r'] + stream_data['r_sem'], alpha=0.5, color=palette_dict[stream])
#      60     axs[axs_ix].errorbar(x_axis, stream_data['r'], yerr=stream_data['r_sem'], label=f"{stream}" if axs_ix == 0 else None, color=palette_dict[stream])
#      63 axs[axs_ix].set_title(f"Feature-gain Model\n{loc}", size=fontsize, y=1.05)
#
# File /om2/user/imgriff/conda_envs/pytorch_2_sva/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File /om2/user/imgriff/conda_envs/pytorch_2_sva/lib/python3.11/site-packages/matplotlib/axes/_axes.py:5504, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5502 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5503                  step=None, **kwargs):
# -> 5504     return self._fill_between_x_or_y(
#    5505         "x", x, y1, y2,
#    5506         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File /om2/user/imgriff/conda_envs/pytorch_2_sva/lib/python3.11/site-packages/matplotlib/axes/_axes.py:5420, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5417     if where.size != ind.size:
#    5418         raise ValueError(f"where size ({where.size}) does not match "
#    5419                          f"{ind_dir} size ({ind.size})")
# -> 5420 where = where & ~functools.reduce(
#    5421     np.logical_or, map(np.ma.getmaskarray, [ind, dep1, dep2]))
#    5423 ind, dep1, dep2 = np.broadcast_arrays(
#    5424     np.atleast_1d(ind), dep1, dep2, subok=True)
#    5426 polys = []
#
# ValueError: operands could not be broadcast together with shapes (9,) (180,)

# %%
tgt_locs
# Out:
# array(['+/- 0° sep.', '+/- 45° sep.', '+/- 5° sep.'], dtype=object)

# %%
## Plot summary_results df \
df_for_agg = act_corrs[act_corrs.model_name.str.contains('main|alt')].copy()
df_for_agg = df_for_agg.groupby(['model_name', 'distractor_condition', 'group', 'layer', 'spatial_cond', 'Stream']).agg({'Pearson\'s r': ['mean', 'sem']}).reset_index()
df_for_agg.columns = ['model_name', 'distractor_condition', 'group', 'layer', 'spatial_cond', 'Stream', 'r', 'r_sem']
df_for_agg = df_for_agg[df_for_agg.layer.str.contains('cochlea|relu')].reset_index(drop=True)

sns.set_style('ticks')
# order = np.sort(results.layer.unique())

# act_corrs

df_for_agg.Stream.rename({'r_tgt_mixture': 'corr(target$_i$, mixture$_i$)', 'r_dist_mixture': 'corr(distractor$_i$, mixture$_i$)'}, inplace=True)

hue_order = ['corr(target$_i$, mixture$_i$)', 'corr(distractor$_i$, mixture$_i$)'] 
# make palette for models in husl 
palette = sns.color_palette("husl", 2)
# make palette dict 
palette_dict = {'corr(target$_i$, mixture$_i$)': palette[1],
                'corr(distractor$_i$, mixture$_i$)': palette[0],}



# add line style dict 
line_style_dict = {'Same sex': '-',
                   'Different sex': '--',
                   'Natural scene': ':'}  
 
# col_wrap = 6

all_models = act_results['model_name'].unique()
n_models = len(all_models)

tgt_locs = df_for_agg.spatial_cond.unique()
n_cols = len(tgt_locs) # trained + rand 
n_rows = 1 # int(np.ceil(n_models / n_cols))
panel_height = 3
fontsize=12
fig, axs = plt.subplots(n_rows, n_cols, figsize=(n_cols* panel_height , n_rows*panel_height), sharex=False, sharey=False)
# axs = axs.flatten()


for axs_ix, loc in enumerate(tgt_locs):
    model_for_panel = df_for_agg[df_for_agg['spatial_cond'] == loc].set_index('layer')
    layers = [l for l in layer_order_dict[model] if 'cochlea' in l or 'relu' in l]
    # try:
    model_for_panel = model_for_panel.loc[layers].reset_index()
    # x_axis = np.linspace(0, 1, len(layers))
    x_axis = np.arange(len(layers))
    for stream in model_for_panel.Stream.unique():
        for distractor_condition in model_for_panel.distractor_condition.unique():
            stream_data = model_for_panel[(model_for_panel['Stream'] == stream) & (model_for_panel['distractor_condition'] == distractor_condition)]
            ls = '-' if 'Same' in distractor_condition else '--'
            # print(stream)
            axs[axs_ix].fill_between(x_axis, stream_data['r'] - stream_data['r_sem'], stream_data['r'] + stream_data['r_sem'], alpha=0.5, color=palette_dict[stream])
            axs[axs_ix].errorbar(x_axis, stream_data['r'], yerr=stream_data['r_sem'], label=f"{stream} {distractor_condition}" if axs_ix == 0 else None, color=palette_dict[stream], fmt=line_style_dict[distractor_condition])
            # axs[axs_ix].set_linestyle(ls)
    # except Exception as e:
    #     print(f"Error with {model}")
    #     print(e)
    #     continue

    axs[axs_ix].set_title(f"Feature-gain Model\n{loc}", size=fontsize, y=1.05)
# axs[1].set_title("Feature-gain Models\nRandom weights", size=fontsize, y=1.05)
# p.axes[0,0].xaxis.labelpad = -0.25

# axs[1].legend().remove() # (loc='center left', bbox_to_anchor=(1, 0.5), title='Stream', frameon=False, title_fontsize=fontsize)
# make panels square 
for ax in axs:
    ax.set_aspect('auto')
    ax.set_box_aspect(1)
    ax.set_ylim(0, 1)
    # ax.set_xlim(-0.5, len(layers) - 0.5)
    # ax.set_xticks([0,1])
    # ax.set_xticklabels(labels=['cochlea', 'relufc'], rotation=0, size=fontsize, )
    ax.set_xticks(x_axis)
    ax.set_xticklabels(labels=layers, rotation=90, size=fontsize-2)
    ax.set(ylim=(0,1))
    ax.set_xlabel("Network Layer", size=fontsize)
    ax.set_ylabel("Pearson's r", size=fontsize)
    # remove spines
    for spine in ax.spines.values():
        spine.set_linewidth(1.5)
    ax.tick_params(axis='both', which='major', length=5, width=1.5)

axs[0].legend(bbox_to_anchor=(-0.5, 1))

# remove legend, and instead plot as colored text 
# top_y_loc = .175
# x_coord = -0.025
# axs[0].text(x_coord, top_y_loc, 'corr(target$_i$, mixture$_i$)', ha='left', va='center', fontsize=fontsize-2, color=palette_dict['corr(target$_i$, mixture$_i$)'])
# axs[0].text(x_coord, top_y_loc - .1, 'corr(distractor$_i$, mixture$_i$)', ha='left', va='center', fontsize=fontsize-2, color=palette_dict['corr(distractor$_i$, mixture$_i$)'])

sns.despine()

# adjust spacing
plt.subplots_adjust(wspace=0.3, hspace=0.3)
# increase size of ticks
# increase size of ticks

# plt.savefig(fig_out_dir / "figure_5_all_arch_traces.pdf", transparent=True, bbox_inches='tight')

# plt.tight_layout()

# %% [markdown]
# ### Run CKA

# %%
import torch

def center_gram(X):
    """Centers the Gram matrix."""
    n = X.size(0)
    H = torch.eye(n, device=X.device) - (1.0 / n) * torch.ones((n, n), device=X.device)
    return H @ X @ H

def gram_linear(X):
    """Computes the linear kernel (Gram) matrix."""
    return X @ X.T

def linear_CKA(X, Y):
    """
    Computes the linear CKA similarity between two representations.
    Inputs:
        X: [n_samples, dim1] tensor
        Y: [n_samples, dim2] tensor
    Output:
        scalar CKA similarity
    """
    # Centered Gram matrices
    K = center_gram(gram_linear(X))
    L = center_gram(gram_linear(Y))
    
    # HSIC (Hilbert-Schmidt Independence Criterion)
    hsic = (K * L).sum()
    
    # Normalization terms
    norm_K = torch.norm(K)
    norm_L = torch.norm(L)

    return hsic / (norm_K * norm_L)


# --- Run CKA ---
h5_fn = analysis_dir/'word_task_v10_main_feature_gain_config_latest_ckpt/word_task_v10_main_feature_gain_config_latest_ckpt_model_activations_0dB_cue_single_source_as_fn_of_sep.h5'
h5 = h5py.File(h5_fn, 'r', swmr=True)

layer_names = set([l.split('_target')[0].replace('_cued', '') for l in h5.keys() if 'target' in l and not  any([str_part in l for str_part in ['_f0', '_loc', '_word']])]) # set to remove duplicates
target_azims = np.unique(h5['target_loc'][:, 0], axis=0) 
distractor_conds = ['same_sex', 'diff_sex', 'nat_scene']

records = []
for layer in tqdm(layer_names):
    for distractor_cond in distractor_conds:
        target_reps = h5[f'{layer}_cued_target']
        same_dist_reps = h5[f'{layer}_cued_{distractor_cond}_dist']
        mixture_reps = h5[f"{layer}_mixture_{distractor_cond.replace('_sex', '') }"]
        for azim in target_azims:
            wanted_rows = np.where(h5['target_loc'][:, 0] == azim)[0]
            tgt_mix_cka_score = linear_CKA(torch.from_numpy(target_reps[wanted_rows]), torch.from_numpy(mixture_reps[wanted_rows]))
            dist_mix_cka_score = linear_CKA(torch.from_numpy(same_dist_reps[wanted_rows]), torch.from_numpy(mixture_reps[wanted_rows]))
            records.append({'layer': layer, 'distractor_condition': distractor_cond, 'spatial_separation': f"{int(azim) * 2}° sep.", 'tgt_mix_cka': tgt_mix_cka_score.item(), 'dist_mix_cka': dist_mix_cka_score.item()})


cka_df = pd.DataFrame.from_records(records)
cka_df['layer'] = cka_df['layer'].str.replace('_block_', '')
cka_df['layer'] = cka_df['layer'].str.replace('norm_coch_rep', 'cochleagram')
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]

# %%
h5.keys()
# Out:
# <KeysViewHDF5 ['attn0_cued_diff_sex_dist', 'attn0_cued_diff_sex_dist_mixture_diff_corr', 'attn0_cued_nat_scene_dist', 'attn0_cued_nat_scene_dist_mixture_nat_scene_corr', 'attn0_cued_same_sex_dist', 'attn0_cued_same_sex_dist_mixture_same_corr', 'attn0_cued_target', 'attn0_cued_target_mixture_diff_corr', 'attn0_cued_target_mixture_nat_scene_corr', 'attn0_cued_target_mixture_same_corr', 'attn0_mixture_diff', 'attn0_mixture_nat_scene', 'attn0_mixture_same', 'attn1_cued_diff_sex_dist', 'attn1_cued_diff_sex_dist_mixture_diff_corr', 'attn1_cued_nat_scene_dist', 'attn1_cued_nat_scene_dist_mixture_nat_scene_corr', 'attn1_cued_same_sex_dist', 'attn1_cued_same_sex_dist_mixture_same_corr', 'attn1_cued_target', 'attn1_cued_target_mixture_diff_corr', 'attn1_cued_target_mixture_nat_scene_corr', 'attn1_cued_target_mixture_same_corr', 'attn1_gains', 'attn1_mixture_diff', 'attn1_mixture_nat_scene', 'attn1_mixture_same', 'attn2_cued_diff_sex_dist', 'attn2_cued_diff_sex_dist_mixture_diff_corr', 'attn2_cued_nat_scene_dist', 'attn2_cued_nat_scene_dist_mixture_nat_scene_corr', 'attn2_cued_same_sex_dist', 'attn2_cued_same_sex_dist_mixture_same_corr', 'attn2_cued_target', 'attn2_cued_target_mixture_diff_corr', 'attn2_cued_target_mixture_nat_scene_corr', 'attn2_cued_target_mixture_same_corr', 'attn2_gains', 'attn2_mixture_diff', 'attn2_mixture_nat_scene', 'attn2_mixture_same', 'attn3_cued_diff_sex_dist', 'attn3_cued_diff_sex_dist_mixture_diff_corr', 'attn3_cued_nat_scene_dist', 'attn3_cued_nat_scene_dist_mixture_nat_scene_corr', 'attn3_cued_same_sex_dist', 'attn3_cued_same_sex_dist_mixture_same_corr', 'attn3_cued_target', 'attn3_cued_target_mixture_diff_corr', 'attn3_cued_target_mixture_nat_scene_corr', 'attn3_cued_target_mixture_same_corr', 'attn3_gains', 'attn3_mixture_diff', 'attn3_mixture_nat_scene', 'attn3_mixture_same', 'attn4_cued_diff_sex_dist', 'attn4_cued_diff_sex_dist_mixture_diff_corr', 'attn4_cued_nat_scene_dist', 'attn4_cued_nat_scene_dist_mixture_nat_scene_corr', 'attn4_cued_same_sex_dist', 'attn4_cued_same_sex_dist_mixture_same_corr', 'attn4_cued_target', 'attn4_cued_target_mixture_diff_corr', 'attn4_cued_target_mixture_nat_scene_corr', 'attn4_cued_target_mixture_same_corr', 'attn4_gains', 'attn4_mixture_diff', 'attn4_mixture_nat_scene', 'attn4_mixture_same', 'attn5_cued_diff_sex_dist', 'attn5_cued_diff_sex_dist_mixture_diff_corr', 'attn5_cued_nat_scene_dist', 'attn5_cued_nat_scene_dist_mixture_nat_scene_corr', 'attn5_cued_same_sex_dist', 'attn5_cued_same_sex_dist_mixture_same_corr', 'attn5_cued_target', 'attn5_cued_target_mixture_diff_corr', 'attn5_cued_target_mixture_nat_scene_corr', 'attn5_cued_target_mixture_same_corr', 'attn5_gains', 'attn5_mixture_diff', 'attn5_mixture_nat_scene', 'attn5_mixture_same', 'attn6_cued_diff_sex_dist', 'attn6_cued_diff_sex_dist_mixture_diff_corr', 'attn6_cued_nat_scene_dist', 'attn6_cued_nat_scene_dist_mixture_nat_scene_corr', 'attn6_cued_same_sex_dist', 'attn6_cued_same_sex_dist_mixture_same_corr', 'attn6_cued_target', 'attn6_cued_target_mixture_diff_corr', 'attn6_cued_target_mixture_nat_scene_corr', 'attn6_cued_target_mixture_same_corr', 'attn6_gains', 'attn6_mixture_diff', 'attn6_mixture_nat_scene', 'attn6_mixture_same', 'attncoch_gains', 'attnfc_cued_diff_sex_dist', 'attnfc_cued_diff_sex_dist_mixture_diff_corr', 'attnfc_cued_nat_scene_dist', 'attnfc_cued_nat_scene_dist_mixture_nat_scene_corr', 'attnfc_cued_same_sex_dist', 'attnfc_cued_same_sex_dist_mixture_same_corr', 'attnfc_cued_target', 'attnfc_cued_target_mixture_diff_corr', 'attnfc_cued_target_mixture_nat_scene_corr', 'attnfc_cued_target_mixture_same_corr', 'attnfc_gains', 'attnfc_mixture_diff', 'attnfc_mixture_nat_scene', 'attnfc_mixture_same', 'cochleagram_cue', 'cochleagram_diff_dist_mixture_diff_corr', 'cochleagram_diff_sex_dist', 'cochleagram_mixture_diff', 'cochleagram_mixture_nat_scene', 'cochleagram_mixture_same', 'cochleagram_nat_scene_dist', 'cochleagram_nat_scene_dist_mixture_nat_scene_corr', 'cochleagram_same_dist_mixture_same_corr' ...
