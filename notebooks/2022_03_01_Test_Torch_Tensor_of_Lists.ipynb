# %%
import torch as ch

# %%
strs = ["ab" * (i+1) for i in range(3)]

# %%
strs
# Out:
# ['ab', 'abab', 'ababab']

# %%
ch.tensor(strs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <module>
# ----> 1 ch.tensor(strs)
#
# ValueError: too many dimensions 'str'
