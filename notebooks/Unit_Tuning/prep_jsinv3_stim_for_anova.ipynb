# %%
import numpy as np 
import h5py
from pathlib import Path 
import IPython.display as ipd 
import pickle 
import h5py
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy.stats as stats
# import src.statsmodels as statsmodels 
import copy
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
jsin_path = Path("/om/user/imgriff/datasets/dataset_word_speaker_noise/JSIN_all_v3/subsets/valid_RQTTZB4C3TJJVLJUWDV72TYMC7S4MNHH")
eg_subfile = 'JSIN_all__run_000_RQTTZB4C3TJJVLJUWDV72TYMC7S4MNHH.h5'

with h5py.File(jsin_path/eg_subfile, 'r') as f:
    for key in f.keys():
        print(f"{key}")

h5 = h5py.File(jsin_path/eg_subfile, 'r')
# Out:
# config
# hash
# meta
# sources
# stimuli

# %%
h5['sources']['signal']['signal']
# Out:
# (16812, 40000)

# %%
n_to_try = 7500

# %%
h5['stimuli']['word_int'].shape
# Out:
# (16812,)

# %%
unique_word_ints, value_counts = np.unique(h5['stimuli']['word_int'][:n_to_try], return_counts=True)
plt.bar(unique_word_ints, value_counts)
plt.xlabel('Word Int')
# Out:
# Text(0.5, 0, 'Word Int')

# %%
unique_speaker_ints, value_counts = np.unique(h5['stimuli']['speaker_int'][:n_to_try], return_counts=True)
plt.bar(unique_speaker_ints, value_counts)
plt.xlabel('speaker int')
# Out:
# Text(0.5, 0, 'speaker int')
