# %%
# !nvidia-smi
# Out:
# Tue Feb 22 14:00:28 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.67       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  On   | 00000000:02:00.0 Off |                  N/A |
# | 34%   59C    P2    72W / 250W |   5465MiB / 11178MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import pandas as pd

# %%
file_csv = pd.read_csv('/om2/data/public/GigaSpeech/data/XL.csv', sep='\t')

# %%
file_csv.wav_len.sum()
# Out:
# 35988340559

# %%
bits = 16 
sr = 16000 

kb_per_sec = (bits * sr) / 1000

# %%
kb_per_sec
# Out:
# 256.0

# %%
total_kb = kb_per_sec * (file_csv.wav_len.sum() / 1000)

# %%
total_tb = total_kb / 1e9

# %%
total_tb
# Out:
# 9.213015183104

# %%
file_csv.wav_len.sum() / 1000   * (kb_per_sec ) / 1e9
# Out:
# 9.213015183104
