# %%
import pickle
import numpy as np
from pathlib import Path
import pandas as pd 
import librosa 
import IPython.display as ipd
import soundfile as sf

# %matplotlib inline 

import matplotlib.pyplot as plt

# %% [markdown]
# ### Re-cut SWC stimuli for better excerpts in binaural experiment

# %%
path_to_dir = Path('/om/user/imgriff/datasets/human_word_rec_SWC_2024')
path_to_dir.mkdir(exist_ok = True, parents=True)

# %%
class_map = pickle.load( open("/om2/user/imgriff/datasets/commonvoice_9/en/cv_800_word_label_to_int_dict.pkl", "rb" ))

# %%
word_list = list(class_map.keys())

# %%
with open("word_list_for_binaural_sentences.pkl", "rb") as f:
	target_word_list =  pickle.load(f)

# %% [markdown]
# ### First, re-screen SWC for excerpts in this list of target words

# %%
swc_fname = '/om2/user/msaddler/spatial_audio_pipeline/assets/swc/manifest_all_words.pdpkl'
swc_main_df = pd.read_pickle(swc_fname)
print(swc_main_df.shape)
# Out:
# (1006299, 13)

# %%
## Throw out bad talkers

bad_talker_names = ['wikipedia', 'viktor-o-ledenyov',  'acerperi']

# %%
swc_main_df = swc_main_df[~swc_main_df.client_id.str.contains('|'.join(bad_talker_names))]

# %%
### remove examples that end too close to edge of file 

tol_in_s = .5 
swc_main_df = swc_main_df[swc_main_df.clip_end_in_s <= (swc_main_df.total_file_duration_in_s - tol_in_s)]

# %%
swc_main_df.shape
# Out:
# (992956, 13)

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
gender_balanced_swc = swc_main_df[swc_main_df.word.isin(target_word_list)].groupby(['gender', 'word']).sample(1, replace=False, random_state=0).reset_index()

# %%
# get distractor df 

distractor_df = swc_main_df[(~swc_main_df.index.isin(gender_balanced_swc.index)) & (swc_main_df.word.isin(target_word_list))]
cue_df = swc_main_df[(~swc_main_df.index.isin(gender_balanced_swc.index))]

# %%
#rename index
gender_balanced_swc.rename(columns={'index':'orig_df_ix'}, inplace=True)

# %%
### Write parent manifest to dir 
out_name = path_to_dir / 'test_stim_orig_manifest.pdpkl'
gender_balanced_swc.to_pickle(out_name)

# %%
gender_balanced_swc.head()
# Out:
#    orig_df_ix       client_id  clip_dur_in_s  clip_end_in_s  clip_start_in_s  \
# 0      601538         laura-s           0.29        1205.07          1204.78
# 1      638828     dolliellama           0.36         737.92           737.56
# 2      249863         ama1016           0.52         371.41           370.89
# 3      127418  popularoutcast           0.47        3399.30          3398.83
# 4      961747          sedola           0.42        1898.92          1898.50
#
#   corpus  gender  gender_int  split  split_int     sr  \
# 0    swc  female           0    NaN          0  44100
# 1    swc  female           0    NaN          0  44100
# 2    swc  female           0    NaN          0  44100
# 3    swc  female           0    NaN          0  44100
# 4    swc  female           0    NaN          0  44100
#
#                                               src_fn  \
# 0  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 1  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 2  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 3  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 4  /scratch2/weka/mcdermott/msaddler/swc/english/...
#
#    total_file_duration_in_s    word
# 0               1796.176689   about
# 1               4871.649524   above
# 2                488.501406  access
# 3               3717.672925  across
# 4               2335.023311  action

# %%
# get manifest for cue and distractor excerpts 

bg_df = swc_main_df[(~swc_main_df.index.isin(gender_balanced_swc.orig_df_ix)) & (swc_main_df.word.isin(word_list))].reset_index()
bg_df.rename(columns={'index':'orig_df_ix'}, inplace=True)
print(bg_df.shape)
# get partition of swc
# Out:
# (317083, 14)

# %% [markdown]
# ### Look at power spectrum of examples

# %%
from scipy.fft import rfft, rfftfreq


def plot_power_spec(wav, axs, sr=16000, title=''):
    # get specturm of the audio
    ps = np.abs(rfft(wav))
    ps_to_db = 20*np.log10(ps/ps.max())
    freqs = rfftfreq(wav.size, 1/sr)
    idx = np.argsort(freqs)
    # axs.semilogx(freqs[idx], ps_to_db[idx], linewidth=0.5, alpha=0.9)
    axs.plot(freqs[idx], ps_to_db[idx], linewidth=0.5, alpha=0.9)
    axs.axis([0, sr//2 + 1000, -100, 5]) # 40 is lowest freq of 40Hz

    axs.set_ylabel('Power spectrum (dB)')
    axs.set_xlabel('Frequency (Hz)')
    axs.set_title(title)
    axs.axvline(16000, linewidth=0.5, color='k', linestyle='--')
    # axs.set_xscale('log')
    # axs.set_ylim(-100, 0)
    return None

# %%
### For row target in gender_balanced_swc load 3 seconds from the src_fn centered on the clip_start_in_s and clip_end_in_s

total_dur = 3 # in seconds
human_dur = 2 # in seconds 
SR = 44_100

def get_window_bounds(clip_dur_in_s, clip_start_in_s, clip_end_in_s, total_dur):
	
	offset = (total_dur  - clip_dur_in_s) / 2
	return clip_start_in_s - offset, clip_end_in_s + offset
# given clip_dur_in_s find lag and lead time around clip_end_in_s and clip_start_in_s

row = gender_balanced_swc.iloc[201]
# print(row)
src_fn = row['src_fn']
clip_start_in_s = row['clip_start_in_s']
clip_end_in_s = row['clip_end_in_s']
clip_dur_in_s = row['clip_dur_in_s']
word = row['word']
onset, offset = get_window_bounds(clip_dur_in_s, clip_start_in_s, clip_end_in_s, total_dur)
# print(onset, offset)
wav, sr = librosa.load(src_fn, sr=SR, offset=onset, duration=total_dur, dtype=np.float32)
print(word)

fig, axs = plt.subplots(figsize=(4,3))
plot_power_spec(wav, axs, title='Real speech natively at 44.1kHz', sr=sr)
ipd.display(ipd.Audio(wav, rate=sr, normalize=False))
# Out:
# issue
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Cut cue, target, and distractor from SWC.
#
# Distractors must use in-vocabulary words to enable confusions

# %%
from tqdm.auto import tqdm

# %%
### Write parent manifest to dir 
out_name = path_to_dir / 'test_stim_orig_manifest.pdpkl'
gender_balanced_swc = pd.read_pickle(out_name)

# %%
### Demo signal samplig proceedure 
np.random.seed(0)
same_sex_dist_df = gender_balanced_swc.copy()
different_sex_dist_df = gender_balanced_swc.copy()

same_sex_dist_df[list(same_sex_dist_df.add_prefix('distractor_').columns)] = None
same_sex_dist_df[[col for col in same_sex_dist_df.columns if 'distractor_' in col]].astype('object')

different_sex_dist_df[list(different_sex_dist_df.add_prefix('distractor_').columns)] = None
different_sex_dist_df[[col for col in different_sex_dist_df.columns if 'distractor_' in col]].astype('object')


# get cue excerpts 
for ix, (orig_df_ix, client_id, clip_dur_in_s, clip_end_in_s, clip_start_in_s, corpus, gender, gender_int, split, split_int, sr, src_fn, total_file_duration_in_s, word) in enumerate(tqdm(gender_balanced_swc.to_numpy())):
	cue_eg = cue_df[(cue_df.client_id == client_id) & (cue_df.word != word) & (cue_df.clip_start_in_s != clip_start_in_s)].sample(1)
	same_dist_eg = distractor_df[(distractor_df.client_id != client_id) & (distractor_df.word != word) & (distractor_df.gender == gender)].sample(1) # get 2 for symmetric
	same_dist_eg2 = distractor_df[(distractor_df.index != same_dist_eg.index[0]) & (distractor_df.client_id != client_id) & (distractor_df.client_id != same_dist_eg.client_id.values[0]) & (distractor_df.word != word) & (distractor_df.word != same_dist_eg.word.values[0]) & (distractor_df.gender == gender)].sample(1) # get 2 for symmetric
	same_dist_eg = pd.concat([same_dist_eg, same_dist_eg2], axis=0)

	diff_dist_eg = distractor_df[(distractor_df.client_id != client_id) & (distractor_df.word != word) & (distractor_df.gender != gender)].sample(1)
	diff_dist_eg2 = distractor_df[(distractor_df.index != diff_dist_eg.index[0]) & (distractor_df.client_id != client_id) & (distractor_df.client_id != diff_dist_eg.client_id.values[0]) & (distractor_df.word != word) & (distractor_df.word != diff_dist_eg.word.values[0]) & (distractor_df.gender != gender)].sample(1)
	diff_dist_eg = pd.concat([diff_dist_eg, diff_dist_eg2], axis=0)
	# add cue to each cue colum n
	cue_eg = cue_eg.add_prefix('cue_')

	same_dist_eg = same_dist_eg.add_prefix('distractor_')
	diff_dist_eg = diff_dist_eg.add_prefix('distractor_')

	# # add same_dist_eg to ix row in same_sex_dist_df
	for column in same_dist_eg.columns:
		same_sex_dist_df.at[ix, column] = same_dist_eg[column].to_numpy().T.tolist()
		different_sex_dist_df.at[ix, column] = diff_dist_eg[column].to_numpy().T.tolist()

	# # add cue to each df 
	same_sex_dist_df.loc[ix, cue_eg.columns] = cue_eg.to_numpy().flatten()
	different_sex_dist_df.loc[ix, cue_eg.columns] = cue_eg.to_numpy().flatten()
# Out:
#   0%|          | 0/976 [00:00<?, ?it/s]

# %%
same_sex_dist_df
# Out:
#      orig_df_ix         client_id  clip_dur_in_s  clip_end_in_s  \
# 0        601538           laura-s           0.29        1205.07
# 1        638828       dolliellama           0.36         737.92
# 2        249863           ama1016           0.52         371.41
# 3        127418    popularoutcast           0.47        3399.30
# 4        961747            sedola           0.42        1898.92
# ..          ...               ...            ...            ...
# 971      732888        jdhowens90           0.49          75.97
# 972      430284  matthewdgonzalez           0.28        3505.95
# 973      359887       jsharpminor           0.26         232.06
# 974      479509      messedrocker           0.38         567.64
# 975      526906         macropode           0.44         361.92
#
#      clip_start_in_s corpus  gender  gender_int  split  split_int  ...  \
# 0            1204.78    swc  female           0    NaN          0  ...
# 1             737.56    swc  female           0    NaN          0  ...
# 2             370.89    swc  female           0    NaN          0  ...
# 3            3398.83    swc  female           0    NaN          0  ...
# 4            1898.50    swc  female           0    NaN          0  ...
# ..               ...    ...     ...         ...    ...        ...  ...
# 971            75.48    swc    male           1    NaN          0  ...
# 972          3505.67    swc    male           1    NaN          0  ...
# 973           231.80    swc    male           1    NaN          0  ...
# 974           567.26    swc    male           1    NaN          0  ...
# 975           361.48    swc    male           1    NaN          0  ...
#
#      cue_clip_start_in_s cue_corpus  cue_gender cue_gender_int cue_split  \
# 0                 207.99        swc      female            0.0       NaN
# 1                1375.01        swc      female            0.0       NaN
# 2                 221.84        swc      female            0.0       NaN
# 3                 182.70        swc      female            0.0       NaN
# 4                2083.73        swc      female            0.0       NaN
# ..                   ...        ...         ...            ...       ...
# 971               966.56        swc        male            1.0       NaN
# 972               539.07        swc        male            1.0       NaN
# 973               807.39        swc        male            1.0       NaN
# 974              1292.19        swc        male            1.0       NaN
# 975               352.14        swc        male            1.0       NaN
#
#     cue_split_int   cue_sr                                         cue_src_fn  \
# 0             0.0  44100.0  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 1             0.0  44100.0  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 2             0.0  44100.0  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 3             0.0  44100.0  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 4             0.0  44100.0  /scratch2/weka/mcdermott/msaddler/swc/english/...
# ..            ...      ...                                                ...
# 971           0.0  44100.0  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 972           0.0  44100.0  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 973           0.0  44100.0  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 974           0.0  44100.0  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 975           0.0  44100.0  /scratch2/weka/mcdermott/msaddler/swc/english/...
#
#     cue_total_file_duration_in_s    cue_word
# 0                    1796.176689        each
# 1                    4871.649524    behavior
# 2                     273.502041    language
# 3                    1526.788934        ties
# 4                    2335.023311        from
# ..                           ...         ...
# 971                  4936.383855  photograph
# 972                  4670.506667        four
# 973                   917.921088       plane
# 974                  1496.289524   splitting
# 975                  1062.424671    external
#
# [976 rows x 41 columns]

# %%
same_sex_dist_df['sex_cond'] = 'same'
different_sex_dist_df['sex_cond'] = 'different'
full_df = pd.concat([same_sex_dist_df.reset_index(drop=True),
                     different_sex_dist_df.reset_index(drop=True)],
                	 axis=0, ignore_index=True)

# %%
## Assertions cue client id should  be the same as the client id of the row
assert all(full_df.client_id == full_df.cue_client_id)
# assert distractor client id is different from the client id of the row

assert all( client_id not in distractor_client_id for client_id, distractor_client_id in full_df[['client_id', 'distractor_client_id']].to_numpy())

# %%
out_name = path_to_dir / 'full_cue_target_distractor_df_w_meta.pdpkl'

full_df.to_pickle(out_name)

# %%
path_to_dir = Path('/om/user/imgriff/datasets/human_word_rec_SWC_2024')

out_name = path_to_dir / 'full_cue_target_distractor_df_w_meta.pdpkl'
full_df = pd.read_pickle(out_name)

# %%
full_df.loc[0, 'cue_src_fn']
# Out:
# '/scratch2/weka/mcdermott/msaddler/swc/english/validArticles/Binary_star/audio_combined.wav'

# %%
# male_fg = full_df[full_df.gender == "male"]
# female_fg = full_df[full_df.gender == "female"]

# female_same = female_fg[female_fg.sex_cond == 'same']
# female_diff = female_fg[female_fg.sex_cond == 'same']

def sample_df(df, group, cond1, cond2, n):
	df_1 = df[df[f'{group}'] == cond1]
	df_2 = df[df[f'{group}'] == cond2]
	df_1_sample = df_1.sample(n=n)
	df_2_sample = df_2[~df_2.word.isin(df_1_sample.word)].sample(n=n)
	df_1_sample = df_1_sample.reset_index()
	df_1_sample.rename(columns={'index':'full_df_index'}, inplace=True)
	df_2_sample = df_2_sample.reset_index()
	df_2_sample.rename(columns={'index':'full_df_index'}, inplace=True)
	return pd.concat([df_1_sample, df_2_sample], axis=0, ignore_index=True)

def get_subset_df(df, n_to_return = 488):
	n_to_samp = n_to_return // 4
	print(n_to_samp)
	female_df = sample_df(df[df.gender == 'female'], 'sex_cond', 'same', 'different',n_to_samp)
	male_df = sample_df(df[(df.gender == 'male') & (~df.word.isin(female_df.word))], 'sex_cond', 'same', 'different', n_to_samp)
	return pd.concat([female_df, male_df], axis=0, ignore_index=True)

fg_samps = get_subset_df(full_df, 480)

print(fg_samps.word.nunique())
print(fg_samps.groupby('gender').sex_cond.value_counts())
# Out:
# 120
# 480
# gender  sex_cond
# female  different    120
#         same         120
# male    different    120
#         same         120
# Name: sex_cond, dtype: int64

# %%
fg_samps
# Out:
#      full_df_index  orig_df_ix         client_id  clip_dur_in_s  \
# 0              156      110069    popularoutcast           0.32
# 1              382      606226           laura-s           0.32
# 2              358      723554          k9taylor           0.40
# 3               84      500323  persian-poet-gal           0.68
# 4              286      961452            sedola           0.31
# ..             ...         ...               ...            ...
# 475           1677      309237            mangst           0.38
# 476           1918      814680          pordaria           0.55
# 477           1831      237826            tonyle           0.29
# 478           1591      770361          cbdroege           0.30
# 479           1550      549121         enviroboy           1.31
#
#      clip_end_in_s  clip_start_in_s corpus  gender  gender_int  split  ...  \
# 0           367.02           366.70    swc  female           0    NaN  ...
# 1          1127.07          1126.75    swc  female           0    NaN  ...
# 2           504.72           504.32    swc  female           0    NaN  ...
# 3          3052.83          3052.15    swc  female           0    NaN  ...
# 4          1532.97          1532.66    swc  female           0    NaN  ...
# ..             ...              ...    ...     ...         ...    ...  ...
# 475         210.04           209.66    swc    male           1    NaN  ...
# 476        3427.52          3426.97    swc    male           1    NaN  ...
# 477        2325.90          2325.61    swc    male           1    NaN  ...
# 478         723.31           723.01    swc    male           1    NaN  ...
# 479         290.96           289.65    swc    male           1    NaN  ...
#
#      cue_corpus  cue_gender cue_gender_int  cue_split cue_split_int   cue_sr  \
# 0           swc      female            0.0        NaN           0.0  44100.0
# 1           swc      female            0.0        NaN           0.0  44100.0
# 2           swc      female            0.0        NaN           0.0  44100.0
# 3           swc      female            0.0        NaN           0.0  44100.0
# 4           swc      female            0.0        NaN           0.0  44100.0
# ..          ...         ...            ...        ...           ...      ...
# 475         swc        male            1.0        NaN           0.0  44100.0
# 476         swc        male            1.0        NaN           0.0  44100.0
# 477         swc        male            1.0        NaN           0.0  44100.0
# 478         swc        male            1.0        NaN           0.0  44100.0
# 479         swc        male            1.0        NaN           0.0  44100.0
#
#                                             cue_src_fn  \
# 0    /scratch2/weka/mcdermott/msaddler/swc/english/...
# 1    /scratch2/weka/mcdermott/msaddler/swc/english/...
# 2    /scratch2/weka/mcdermott/msaddler/swc/english/...
# 3    /scratch2/weka/mcdermott/msaddler/swc/english/...
# 4    /scratch2/weka/mcdermott/msaddler/swc/english/...
# ..                                                 ...
# 475  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 476  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 477  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 478  /scratch2/weka/mcdermott/msaddler/swc/english/...
# 479  /scratch2/weka/mcdermott/msaddler/swc/english/...
#
#     cue_total_file_duration_in_s  cue_word   sex_cond
# 0                    2373.870295   attempt       same
# 1                    2294.249070      bill       same
# 2                     541.020590    gordon       same
# 3                    3092.990839  attended       same
# 4                    2335.023311  students       same
# ..                           ...       ...        ...
# 475                  2220.232562  improves  different
# 476                  3362.795102   israeli  different
# 477                   868.514830    ohioan  different
# 478                  2057.446168     style  different
# 479                   561.007166    marvin  different
#
# [480 rows x 43 columns]

# %%
## Dev dataset class
from importlib import reload

import corpus.binaural_swc_currated_pd as dataset_class
reload(dataset_class)
import torch
from pathlib import Path
from tqdm import tqdm

SWCHumanExperimentStimDataset = dataset_class.SWCHumanExperimentStimDataset

# %%
path_to_dir = Path('/om/user/imgriff/datasets/human_word_rec_SWC_2024')

out_name = path_to_dir / 'full_cue_target_distractor_df_w_meta.pdpkl'

# %%
dataset = SWCHumanExperimentStimDataset(path=out_name, run_all_stim=False)

# %%
dataloader = torch.utils.data.DataLoader(dataset, batch_size=10, shuffle=False, num_workers=0)

# %%
for batch in tqdm(dataloader):
    continue
# Out:
#  20%|██        | 10/49 [00:02<00:11,  3.32it/s]/om2/user/imgriff/conda_envs/torch_11_cuda_11_pitch/lib/python3.9/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# 100%|██████████| 49/49 [00:16<00:00,  2.92it/s]

# %% [markdown]
# ## Write stim for human experiment

# %%
import librosa
import pandas as pd 
from pathlib import Path
from tqdm.auto import tqdm
import pickle 
import sys 
sys.path.append('../../datasets/spatial_audio_pipeline/spatial_audio_util/')
import util_audio 
import soxr
import soundfile as sf


outdir = Path("/om/user/imgriff/datasets/human_word_rec_SWC_2024/sounds")
outdir.mkdir(exist_ok=True, parents=True)

path_to_dir = Path('/om/user/imgriff/datasets/human_word_rec_SWC_2024')

full_stim_df = pd.read_pickle(path_to_dir / 'full_cue_target_distractor_df_w_meta.pdpkl')

# %%
cue_out_dir = outdir / "cue_excerpts"
target_out_dir = outdir / "target_excerpts"
distractor_out_dir = outdir / "distractor_excerpts"

# make dirs if not exist 
cue_out_dir.mkdir(exist_ok=True, parents=True)
target_out_dir.mkdir(exist_ok=True, parents=True)
distractor_out_dir.mkdir(exist_ok=True, parents=True)

# %%
def get_window_bounds(clip_dur_in_s, clip_start_in_s, clip_end_in_s, total_dur=3):
	offset = (total_dur  - clip_dur_in_s) / 2
	return clip_start_in_s - offset, clip_end_in_s + offset

# %%
SR = 44_100
signal_dur = 2
win_dur = 10 # ms 


### Load and save cue, target, distractor excerpts for each rown in full_stim_df


for ix in tqdm(range(full_stim_df.shape[0]), total=full_stim_df.shape[0]):
	row = full_stim_df.iloc[ix]

	# get target 
	src_fn = row['src_fn']
	clip_start_in_s = row['clip_start_in_s']
	clip_end_in_s = row['clip_end_in_s']
	clip_dur_in_s = row['clip_dur_in_s'] 
	word = row['word']
	onset, offset = get_window_bounds(clip_dur_in_s, clip_start_in_s, clip_end_in_s, signal_dur)
	# print(clip_dur_in_s, onset, clip_start_in_s)

	target_wav, _ = librosa.load(src_fn, sr=SR, offset=onset, duration=signal_dur, dtype=np.float32)
	target_wav = util_audio.pad_or_trim_to_len(target_wav, int(SR * signal_dur))
	target_wav = util_audio.ramp_hann(target_wav, win_dur, SR)
	target_wav = util_audio.set_dBSPL(target_wav, 60)

	target_f_name = target_out_dir / f"full_df_ix_{ix:04}_{word}-{row['client_id']}.wav"
	sf.write(target_f_name, target_wav, samplerate=SR)

	cue_src_fn = row['cue_src_fn']
	cue_clip_start_in_s = row['cue_clip_start_in_s']
	cue_clip_end_in_s = row['cue_clip_end_in_s']
	cue_clip_dur_in_s = row['cue_clip_dur_in_s']
	cue_onset, cue_offset = get_window_bounds(cue_clip_dur_in_s, cue_clip_start_in_s, cue_clip_end_in_s, signal_dur)
	cue_wav, _ = librosa.load(cue_src_fn, sr=SR, offset=cue_onset, duration=signal_dur, dtype=np.float32)
	cue_wav = util_audio.pad_or_trim_to_len(cue_wav, int(SR * signal_dur))
	cue_wav = util_audio.ramp_hann(cue_wav, win_dur, SR)
	cue_wav = util_audio.set_dBSPL(cue_wav, 60)

	cue_f_name = cue_out_dir / f"full_df_ix_{ix:04}_{row['cue_word']}-{row['cue_client_id']}.wav"
	sf.write(cue_f_name, cue_wav, samplerate=SR)


	dist_src_fn = row['distractor_src_fn'][0]
	dist_clip_start_in_s = row['distractor_clip_start_in_s'][0]
	dist_clip_end_in_s = row['distractor_clip_end_in_s'][0]
	dist_clip_dur_in_s = row['distractor_clip_dur_in_s'][0]
	dist_word_1 = row['distractor_word'][0]

	dist_onset, dist_offset = get_window_bounds(dist_clip_dur_in_s, dist_clip_start_in_s, dist_clip_end_in_s, signal_dur)
	distractor_1_wav, _ = librosa.load(dist_src_fn, sr=SR, offset=dist_onset, duration=signal_dur, dtype=np.float32)
	distractor_1_wav = util_audio.pad_or_trim_to_len(distractor_1_wav, int(SR * signal_dur))
	distractor_1_wav = util_audio.ramp_hann(distractor_1_wav, win_dur, SR)
	distractor_1_wav = util_audio.set_dBSPL(distractor_1_wav, 60)

	dist_f_name = distractor_out_dir / f"full_df_ix_{ix:04}_{dist_word_1}-{row['distractor_client_id'][0]}_eg_0.wav"
	sf.write(dist_f_name, distractor_1_wav, samplerate=SR)


	dist_src_fn = row['distractor_src_fn'][1]
	dist_clip_start_in_s = row['distractor_clip_start_in_s'][1]
	dist_clip_end_in_s = row['distractor_clip_end_in_s'][1]
	dist_clip_dur_in_s = row['distractor_clip_dur_in_s'][1]
	dist_word_2 = row['distractor_word'][1]
	dist_onset, dist_offset = get_window_bounds(dist_clip_dur_in_s, dist_clip_start_in_s, dist_clip_end_in_s, signal_dur)
	distractor_2_wav, _ = librosa.load(dist_src_fn, sr=SR, offset=dist_onset, duration=signal_dur, dtype=np.float32)
	distractor_2_wav = util_audio.pad_or_trim_to_len(distractor_2_wav, int(SR * signal_dur))
	distractor_2_wav = util_audio.ramp_hann(distractor_2_wav, win_dur, SR)
	distractor_2_wav = util_audio.set_dBSPL(distractor_2_wav, 60)

	dist_f_name = distractor_out_dir / f"full_df_ix_{ix:04}_{dist_word_2}-{row['distractor_client_id'][1]}_eg_1.wav"
	sf.write(dist_f_name, distractor_2_wav, samplerate=SR)
	# break
# Out:
#   0%|          | 0/1952 [00:00<?, ?it/s]

# %%
# Out:
# 975

# %%
# !ls {distractor_out_dir}
# Out:
# full_df_ix_0000_police-popularoutcast_eg_1.wav
# full_df_ix_0000_present-persian-poet-gal_eg_0.wav
# full_df_ix_0001_later-flyingtoaster_eg_1.wav
# full_df_ix_0001_search-popularoutcast_eg_0.wav
# full_df_ix_0002_regular-popularoutcast_eg_0.wav
# full_df_ix_0002_which-fang-aili_eg_1.wav
# full_df_ix_0003_country-laurahale_eg_1.wav
# full_df_ix_0003_course-etoile_eg_0.wav
# full_df_ix_0004_believe-gonzonoir_eg_0.wav
# full_df_ix_0004_found-popularoutcast_eg_1.wav
# full_df_ix_0005_first-k9taylor_eg_1.wav
# full_df_ix_0005_named-flyingtoaster_eg_0.wav
# full_df_ix_0006_again-dolliellama_eg_0.wav
# full_df_ix_0006_within-laurenpt015_eg_1.wav
# full_df_ix_0007_often-1904-cc_eg_1.wav
# full_df_ix_0007_seven-flyingtoaster_eg_0.wav
# full_df_ix_0008_based-laura-domineau_eg_1.wav
# full_df_ix_0008_their-lily5lace_eg_0.wav
# full_df_ix_0009_include-pinangjawa_eg_1.wav
# full_df_ix_0009_since-popularoutcast_eg_0.wav
# full_df_ix_0010_english-lily5lace_eg_0.wav
# full_df_ix_0010_several-laurascudder_eg_1.wav
# full_df_ix_0011_along-laurascudder_eg_1.wav
# full_df_ix_0011_human-ama1016_eg_0.wav
# full_df_ix_0012_person-ama1016_eg_0.wav
# full_df_ix_0012_search-popularoutcast_eg_1.wav
# full_df_ix_0013_around-popularoutcast_eg_1.wav
# full_df_ix_0013_british-gonzonoir_eg_0.wav
# full_df_ix_0014_desert-dolliellama_eg_1.wav
# full_df_ix_0014_former-flyingtoaster_eg_0.wav
# full_df_ix_0015_front-popularoutcast_eg_1.wav
# full_df_ix_0177_major-flyingtoaster_eg_1.wav
# full_df_ix_0178_often-popularoutcast_eg_1.wav
# full_df_ix_0178_these-laura-s_eg_0.wav
# full_df_ix_0179_people-laura-s_eg_0.wav
# full_df_ix_0179_usually-thatgirltayler_eg_1.wav
# full_df_ix_0180_america-persian-poet-gal_eg_0.wav
# full_df_ix_0180_their-dolliellama_eg_1.wav
# full_df_ix_0181_police-popularoutcast_eg_0.wav
# full_df_ix_0181_trying-flyingtoaster_eg_1.wav
# full_df_ix_0182_hundred-persian-poet-gal_eg_1.wav
# full_df_ix_0182_until-popularoutcast_eg_0.wav
# full_df_ix_0183_human-flyingtoaster_eg_0.wav
# full_df_ix_0183_under-laurascudder_eg_1.wav
# full_df_ix_0184_often-flyingtoaster_eg_0.wav
# full_df_ix_0184_which-dolliellama_eg_1.wav
# full_df_ix_0185_cannot-laura-s_eg_1.wav
# full_df_ix_0185_their-flyingtoaster_eg_0.wav
# full_df_ix_0186_based-k9taylor_eg_1.wav
# full_df_ix_0186_british-laura-s_eg_0.wav
# full_df_ix_0187_people-ama1016_eg_1.wav
# full_df_ix_0187_since-flyingtoaster_eg_0.wav
# full_df_ix_0188_include-popularoutcast_eg_0.wav
# full_df_ix_0188_written-elizabeyth_eg_1.wav
# full_df_ix_0189_outside-popularoutcast_eg_0.wav
# full_df_ix_0189_winter-potteryfreak_eg_1.wav
# full_df_ix_0190_battle-acather96_eg_1.wav
# full_df_ix_0190_towards-flyingtoaster_eg_0.wav
# full_df_ix_0191_after-persian-poet-gal_eg_1.wav
# full_df_ix_0191_america-popularoutcast_eg_0.wav
# full_df_ix_0192_above-popularoutcast_eg_0.wav
# full_df_ix_0192_complex-persian-poet-gal_eg_1.wav
# full_df_ix_0193_ancient-dolliellama_eg_1.wav
# full_df_ix_0193_planet-laura-s_eg_0.wav
# full_df_ix_0194_against-popularoutcast_eg_1.wav
# full_df_ix_0194_system-laura-s_eg_0.wav
# full_df_ix_0195_airport-popularoutcast_eg_1.wav
# full_df_ix_0195_enough-persian-poet-gal_eg_0.wav
# full_df_ix_0196_county-laura-domineau_eg_1.wav
# full_df_ix_0196_should-flyingtoaster_eg_0.wav
# full_df_ix_0197_became-ama1016_eg_0.wav
# full_df_ix_0197_stage-laura-s_eg_1.wav
# full_df_ix_0198_former-laura-domineau_eg_0.wav
# full_df_ix_0198_matter-dolliellama_eg_1.wav
# full_df_ix_0199_other-laurahale_eg_0.wav
# full_df_ix_0199_player-popularoutcast_eg_1.wav
# full_df_ix_0200_known-popularoutcast_eg_0.wav
# full_df_ix_0200_matter-flyingtoaster_eg_1.wav
# full_df_ix_0201_after-laurahale_eg_1.wav
# full_df_ix_0201_space-flyingtoaster_eg_0.wav
# full_df_ix_0202_called-gonzonoir_eg_0.wav
# full_df_ix_0202_similar-flyingtoaster_eg_1.wav
# full_df_ix_0203_another-ama1016_eg_1.wav
# full_df_ix_0203_since-theexistentialist383_eg_0.wav
# full_df_ix_0204_could-persian-poet-gal_eg_1.wav
# full_df_ix_0204_which-acather96_eg_0.wav
# full_df_ix_0205_company-theexistentialist686_eg_1.wav
# full_df_ix_0205_every-gorillawarfare_eg_0.wav
# full_df_ix_0206_eight-popularoutcast_eg_0.wav
# full_df_ix_0206_using-flyingtoaster_eg_1.wav
# full_df_ix_0207_current-eleaverton_eg_0.wav
# full_df_ix_0207_later-gorillawarfare_eg_1.wav
# full_df_ix_0208_united-popularoutcast_eg_0.wav
# full_df_ix_0208_video-1904-cc_eg_1.wav
# full_df_ix_0209_however-laura-s_eg_0.wav
# full_df_ix_0209_union-popularoutcast_eg_1.wav
# full_df_ix_0210_since-popularoutcast_eg_0.wav
# full_df_ix_0210_while-sctechlaw_eg_1.wav
# full_df_ix_0211_include-popularoutcast_eg_0.wav
# full_df_ix_0211_later-laura-s_eg_1.wav
# full_df_ix_0212_other-popularoutcast_eg_0.wav
# full_df_ix_0212_played-persian-poet-gal_eg_1.wav
# full_df_ix_0213_minor-dolliellama_eg_0.wav
# full_df_ix_0213_while-flyingtoaster_eg_1.wav
# full_df_ix_0214_george-laura-s_eg_1.wav
# full_df_ix_0214_their-flyingtoaster_eg_0.wav
# full_df_ix_0215_nearby-persian-poet-gal_eg_0.wav
# full_df_ix_0215_through-laura-s_eg_1.wav
# full_df_ix_0216_human-popularoutcast_eg_0.wav
# full_df_ix_0216_without-dolliellama_eg_1.wav
# full_df_ix_0217_system-laura-s_eg_0.wav
# full_df_ix_0217_three-dolliellama_eg_1.wav
# full_df_ix_0218_class-flyingtoaster_eg_0.wav
# full_df_ix_0218_light-ama1016_eg_1.wav
# full_df_ix_0219_career-flyingtoaster_eg_1.wav
# full_df_ix_0219_usually-thatgirltayler_eg_0.wav
# full_df_ix_0220_event-persian-poet-gal_eg_1.wav
# full_df_ix_0220_hundred-gorillawarfare_eg_0.wav
# full_df_ix_0221_cover-theexistentialist686_eg_1.wav
# full_df_ix_0221_human-flyingtoaster_eg_0.wav
# full_df_ix_0222_modern-potteryfreak_eg_0.wav
# full_df_ix_0222_seven-flyingtoaster_eg_1.wav
# full_df_ix_0223_became-persian-poet-gal_eg_0.wav
# full_df_ix_0223_three-theexistentialist686_eg_1.wav
# full_df_ix_0224_eight-laurahale_eg_1.wav
# full_df_ix_0224_light-laura-s_eg_0.wav
# full_df_ix_0225_become-potteryfreak_eg_1.wav
# full_df_ix_0225_short-flyingtoaster_eg_0.wav
# full_df_ix_0226_coming-sctechlaw_eg_0.wav
# full_df_ix_0226_service-flyingtoaster_eg_1.wav
# full_df_ix_0227_during-gorillawarfare_eg_0.wav
# full_df_ix_0227_found-popularoutcast_eg_1.wav
# full_df_ix_0228_morning-jonjalin_eg_0.wav
# full_df_ix_0228_second-lily5lace_eg_1.wav
# full_df_ix_0229_include-sedola_eg_1.wav
# full_df_ix_0229_james-lily5lace_eg_0.wav
# full_df_ix_0230_series-popularoutcast_eg_1.wav
# full_df_ix_0230_while-laura-s_eg_0.wav
# full_df_ix_0231_money-popularoutcast_eg_0.wav
# full_df_ix_0312_morning-laurascudder_eg_1.wav
# full_df_ix_0313_found-persian-poet-gal_eg_1.wav
# full_df_ix_0313_remains-popularoutcast_eg_0.wav
# full_df_ix_0314_three-vaslittlecrow_eg_1.wav
# full_df_ix_0314_which-bowie-media_eg_0.wav
# full_df_ix_0315_first-sedola_eg_1.wav
# full_df_ix_0315_united-popularoutcast_eg_0.wav
# full_df_ix_0316_having-ama1016_eg_1.wav
# full_df_ix_0316_while-popularoutcast_eg_0.wav
# full_df_ix_0317_making-lily5lace_eg_0.wav
# full_df_ix_0317_social-laura-s_eg_1.wav
# full_df_ix_0318_first-laura-s_eg_0.wav
# full_df_ix_0318_found-gorillawarfare_eg_1.wav
# full_df_ix_0319_between-ama1016_eg_1.wav
# full_df_ix_0319_under-dolliellama_eg_0.wav
# full_df_ix_0320_eight-popularoutcast_eg_0.wav
# full_df_ix_0320_related-ama1016_eg_1.wav
# full_df_ix_0321_capital-popularoutcast_eg_0.wav
# full_df_ix_0321_until-lily5lace_eg_1.wav
# full_df_ix_0322_other-lily5lace_eg_1.wav
# full_df_ix_0322_their-sedola_eg_0.wav
# full_df_ix_0323_local-dolliellama_eg_1.wav
# full_df_ix_0323_people-popularoutcast_eg_0.wav
# full_df_ix_0324_student-persian-poet-gal_eg_0.wav
# full_df_ix_0324_website-popularoutcast_eg_1.wav
# full_df_ix_0325_another-gonzonoir_eg_1.wav
# full_df_ix_0325_include-popularoutcast_eg_0.wav
# full_df_ix_0326_america-flyingtoaster_eg_1.wav
# full_df_ix_0326_british-laurahale_eg_0.wav
# full_df_ix_0327_first-flyingtoaster_eg_1.wav
# full_df_ix_0327_which-popularoutcast_eg_0.wav
# full_df_ix_0328_created-persian-poet-gal_eg_1.wav
# full_df_ix_0328_further-laurascudder_eg_0.wav
# full_df_ix_0329_period-dolliellama_eg_1.wav
# full_df_ix_0329_rather-flyingtoaster_eg_0.wav
# full_df_ix_0330_council-bowie-media_eg_1.wav
# full_df_ix_0330_united-popularoutcast_eg_0.wav
# full_df_ix_0331_above-lily5lace_eg_1.wav
# full_df_ix_0331_always-potteryfreak_eg_0.wav
# full_df_ix_0332_almost-thatgirltayler_eg_0.wav
# full_df_ix_0332_order-popularoutcast_eg_1.wav
# full_df_ix_0333_human-flyingtoaster_eg_0.wav
# full_df_ix_0333_while-persian-poet-gal_eg_1.wav
# full_df_ix_0334_native-popularoutcast_eg_1.wav
# full_df_ix_0334_twenty-thatgirltayler_eg_0.wav
# full_df_ix_0335_opened-laura-domineau_eg_1.wav
# full_df_ix_0335_success-flyingtoaster_eg_0.wav
# full_df_ix_0336_court-elizabeyth_eg_1.wav
# full_df_ix_0336_their-laura-s_eg_0.wav
# full_df_ix_0337_lived-popularoutcast_eg_0.wav
# full_df_ix_0337_three-acather96_eg_1.wav
# full_df_ix_0338_located-popularoutcast_eg_1.wav
# full_df_ix_0338_various-sedola_eg_0.wav
# full_df_ix_0339_served-flyingtoaster_eg_0.wav
# full_df_ix_0339_several-popularoutcast_eg_1.wav
# full_df_ix_0367_eight-potteryfreak_eg_1.wav
# full_df_ix_0367_later-gorillawarfare_eg_0.wav
# full_df_ix_0368_based-flyingtoaster_eg_0.wav
# full_df_ix_0368_early-laura-s_eg_1.wav
# full_df_ix_0369_mother-flyingtoaster_eg_0.wav
# full_df_ix_0369_source-1904-cc_eg_1.wav
# full_df_ix_0370_between-popularoutcast_eg_0.wav
# full_df_ix_0370_their-flyingtoaster_eg_1.wav
# full_df_ix_0371_house-popularoutcast_eg_0.wav
# full_df_ix_0371_three-laurahale_eg_1.wav
# full_df_ix_0372_leave-popularoutcast_eg_0.wav
# full_df_ix_0372_unique-ama1016_eg_1.wav
# full_df_ix_0373_floor-dolliellama_eg_0.wav
# full_df_ix_0373_still-flyingtoaster_eg_1.wav
# full_df_ix_0374_certain-etoile_eg_0.wav
# full_df_ix_0374_major-popularoutcast_eg_1.wav
# full_df_ix_0375_because-etoile_eg_1.wav
# full_df_ix_0375_under-popularoutcast_eg_0.wav
# full_df_ix_0376_other-bowie-media_eg_1.wav
# full_df_ix_0376_system-theexistentialist686_eg_0.wav
# full_df_ix_0377_first-persian-poet-gal_eg_0.wav
# full_df_ix_0377_point-gorillawarfare_eg_1.wav
# full_df_ix_0378_after-persian-poet-gal_eg_1.wav
# full_df_ix_0378_which-popularoutcast_eg_0.wav
# full_df_ix_0379_based-laura-s_eg_1.wav
# full_df_ix_0379_white-flyingtoaster_eg_0.wav
# full_df_ix_0380_lived-flyingtoaster_eg_1.wav
# full_df_ix_0380_which-laura-s_eg_0.wav
# full_df_ix_0381_about-gorillawarfare_eg_0.wav
# full_df_ix_0381_first-persian-poet-gal_eg_1.wav
# full_df_ix_0382_created-theexistentialist686_eg_0.wav
# full_df_ix_0382_several-k9taylor_eg_1.wav
# full_df_ix_0383_civil-ama1016_eg_1.wav
# full_df_ix_0383_their-popularoutcast_eg_0.wav
# full_df_ix_0384_called-dolliellama_eg_0.wav
# full_df_ix_0384_found-gonzonoir_eg_1.wav
# full_df_ix_0385_south-popularoutcast_eg_0.wav
# full_df_ix_0385_three-persian-poet-gal_eg_1.wav
# full_df_ix_0386_college-flyingtoaster_eg_1.wav
# full_df_ix_0386_primary-laura-s_eg_0.wav
# full_df_ix_0387_state-alanasings_eg_0.wav
# full_df_ix_0387_which-popularoutcast_eg_1.wav
# full_df_ix_0388_study-thatgirltayler_eg_1.wav
# full_df_ix_0388_which-popularoutcast_eg_0.wav
# full_df_ix_0389_europe-etoile_eg_1.wav
# full_df_ix_0389_offer-alanasings_eg_0.wav
# full_df_ix_0390_market-popularoutcast_eg_1.wav
# full_df_ix_0390_might-laura-s_eg_0.wav
# full_df_ix_0391_after-popularoutcast_eg_1.wav
# full_df_ix_0391_their-dolliellama_eg_0.wav
# full_df_ix_0392_include-slashdottir_eg_1.wav
# full_df_ix_0392_needed-laurascudder_eg_0.wav
# full_df_ix_0393_instead-gorillawarfare_eg_1.wav
# full_df_ix_0393_simply-popularoutcast_eg_0.wav
# full_df_ix_0394_least-laura-s_eg_1.wav
# full_df_ix_0394_music-popularoutcast_eg_0.wav
# full_df_ix_0395_season-popularoutcast_eg_0.wav
# full_df_ix_0395_series-bowie-media_eg_1.wav
# full_df_ix_0396_africa-popularoutcast_eg_1.wav
# full_df_ix_0396_while-lily5lace_eg_0.wav
# full_df_ix_0397_first-gorillawarfare_eg_0.wav
# full_df_ix_0397_world-laurahale_eg_1.wav
# full_df_ix_0398_heavy-gorillawarfare_eg_0.wav
# full_df_ix_0398_street-flyingtoaster_eg_1.wav
# full_df_ix_0399_against-flyingtoaster_eg_0.wav
# full_df_ix_0399_three-popularoutcast_eg_1.wav
# full_df_ix_0400_river-persian-poet-gal_eg_1.wav
# full_df_ix_0400_under-laura-s_eg_0.wav
# full_df_ix_0401_point-dolliellama_eg_0.wav
# full_df_ix_0401_thought-elizabeyth_eg_1.wav
# full_df_ix_0402_after-laurahale_eg_0.wav
# full_df_ix_0402_turned-popularoutcast_eg_1.wav
# full_df_ix_0403_range-popularoutcast_eg_1.wav
# full_df_ix_0403_these-persian-poet-gal_eg_0.wav
# full_df_ix_0404_central-popularoutcast_eg_1.wav
# full_df_ix_0404_those-persian-poet-gal_eg_0.wav
# full_df_ix_0405_divided-flyingtoaster_eg_0.wav
# full_df_ix_0405_police-gonzonoir_eg_1.wav
# full_df_ix_0406_become-ama1016_eg_1.wav
# full_df_ix_0406_travel-gorillawarfare_eg_0.wav
# full_df_ix_0407_under-laura-s_eg_1.wav
# full_df_ix_0407_united-gorillawarfare_eg_0.wav
# full_df_ix_0408_other-popularoutcast_eg_1.wav
# full_df_ix_0408_these-dolliellama_eg_0.wav
# full_df_ix_0409_cause-flyingtoaster_eg_1.wav
# full_df_ix_0409_either-persian-poet-gal_eg_0.wav
# full_df_ix_0410_access-persian-poet-gal_eg_0.wav
# full_df_ix_0410_class-flyingtoaster_eg_1.wav
# full_df_ix_0411_quickly-gorillawarfare_eg_1.wav
# full_df_ix_0411_these-popularoutcast_eg_0.wav
# full_df_ix_0412_elected-persian-poet-gal_eg_0.wav
# full_df_ix_0412_known-laura-s_eg_1.wav
# full_df_ix_0413_became-laura-s_eg_1.wav
# full_df_ix_0413_widely-theexistentialist383_eg_0.wav
# full_df_ix_0414_current-literatpj_eg_0.wav
# full_df_ix_0414_project-laura-domineau_eg_1.wav
# full_df_ix_0415_german-potteryfreak_eg_0.wav
# full_df_ix_0415_using-popularoutcast_eg_1.wav
# full_df_ix_0416_after-gorillawarfare_eg_0.wav
# full_df_ix_0416_might-laura-s_eg_1.wav
# full_df_ix_0417_about-popularoutcast_eg_1.wav
# full_df_ix_0417_large-sedola_eg_0.wav
# full_df_ix_0418_close-flyingtoaster_eg_1.wav
# full_df_ix_0418_father-persian-poet-gal_eg_0.wav
# full_df_ix_0419_culture-flyingtoaster_eg_0.wav
# full_df_ix_0419_father-laurenpt015_eg_1.wav
# full_df_ix_0420_after-popularoutcast_eg_1.wav
# full_df_ix_0420_heard-laura-s_eg_0.wav
# full_df_ix_0421_himself-flyingtoaster_eg_0.wav
# full_df_ix_0421_place-jonjalin_eg_1.wav
# full_df_ix_0422_charge-persian-poet-gal_eg_1.wav
# full_df_ix_0422_result-gorillawarfare_eg_0.wav
# full_df_ix_0423_might-popularoutcast_eg_0.wav
# full_df_ix_0423_twice-flyingtoaster_eg_1.wav
# full_df_ix_0424_between-pinangjawa_eg_1.wav
# full_df_ix_0424_every-laura-s_eg_0.wav
# full_df_ix_0425_police-flyingtoaster_eg_0.wav
# full_df_ix_0425_problem-ama1016_eg_1.wav
# full_df_ix_0426_between-laura-s_eg_1.wav
# full_df_ix_0426_needed-dolliellama_eg_0.wav
# full_df_ix_0427_around-laura-s_eg_0.wav
# full_df_ix_0427_second-lily5lace_eg_1.wav
# full_df_ix_0428_group-popularoutcast_eg_1.wav
# full_df_ix_0428_taking-laura-s_eg_0.wav
# full_df_ix_0429_green-laurenpt015_eg_1.wav
# full_df_ix_0429_water-laurahale_eg_0.wav
# full_df_ix_0430_three-flyingtoaster_eg_0.wav
# full_df_ix_0430_working-persian-poet-gal_eg_1.wav
# full_df_ix_0431_using-vaslittlecrow_eg_1.wav
# full_df_ix_0431_which-popularoutcast_eg_0.wav
# full_df_ix_0432_brother-k9taylor_eg_1.wav
# full_df_ix_0432_known-popularoutcast_eg_0.wav
# full_df_ix_0433_found-gonzonoir_eg_0.wav
# full_df_ix_0433_people-ama1016_eg_1.wav
# full_df_ix_0434_popular-laurahale_eg_1.wav
# full_df_ix_0434_which-sophus-bie_eg_0.wav
# full_df_ix_0435_africa-laurahale_eg_1.wav
# full_df_ix_0435_longer-popularoutcast_eg_0.wav
# full_df_ix_0436_civil-laura-s_eg_1.wav
# full_df_ix_0436_season-popularoutcast_eg_0.wav
# full_df_ix_0437_support-laura-s_eg_0.wav
# full_df_ix_0437_three-theexistentialist383_eg_1.wav
# full_df_ix_0438_given-popularoutcast_eg_0.wav
# full_df_ix_0438_these-persian-poet-gal_eg_1.wav
# full_df_ix_0439_first-popularoutcast_eg_0.wav
# full_df_ix_0439_rather-gorillawarfare_eg_1.wav
# full_df_ix_0440_field-popularoutcast_eg_1.wav
# full_df_ix_0440_human-flyingtoaster_eg_0.wav
# full_df_ix_0441_series-theexistentialist686_eg_1.wav
# full_df_ix_0441_space-sedola_eg_0.wav
# full_df_ix_0442_first-gorillawarfare_eg_0.wav
# full_df_ix_0442_several-flyingtoaster_eg_1.wav
# full_df_ix_0443_lower-laura-s_eg_1.wav
# full_df_ix_0443_number-dolliellama_eg_0.wav
# full_df_ix_0444_below-popularoutcast_eg_1.wav
# full_df_ix_0444_school-pinangjawa_eg_0.wav
# full_df_ix_0445_force-bernstein2291_eg_0.wav
# full_df_ix_0445_light-laura-s_eg_1.wav
# full_df_ix_0446_process-laura-domineau_eg_0.wav
# full_df_ix_0446_today-persian-poet-gal_eg_1.wav
# full_df_ix_0447_better-dolliellama_eg_0.wav
# full_df_ix_0447_public-flyingtoaster_eg_1.wav
# full_df_ix_0448_canada-potteryfreak_eg_1.wav
# full_df_ix_0475_website-gorillawarfare_eg_1.wav
# full_df_ix_0476_first-flyingtoaster_eg_1.wav
# full_df_ix_0476_native-popularoutcast_eg_0.wav
# full_df_ix_0477_david-k9taylor_eg_0.wav
# full_df_ix_0477_which-laura-s_eg_1.wav
# full_df_ix_0478_during-flyingtoaster_eg_0.wav
# full_df_ix_0478_shortly-laurascudder_eg_1.wav
# full_df_ix_0479_battle-bowie-media_eg_0.wav
# full_df_ix_0479_large-1904-cc_eg_1.wav
# full_df_ix_0480_along-flyingtoaster_eg_1.wav
# full_df_ix_0480_while-popularoutcast_eg_0.wav
# full_df_ix_0481_early-popularoutcast_eg_1.wav
# full_df_ix_0481_other-ama1016_eg_0.wav
# full_df_ix_0482_career-flyingtoaster_eg_0.wav
# full_df_ix_0482_result-popularoutcast_eg_1.wav
# full_df_ix_0483_along-laurascudder_eg_0.wav
# full_df_ix_0483_other-dolliellama_eg_1.wav
# full_df_ix_0484_being-dolliellama_eg_1.wav
# full_df_ix_0484_george-flyingtoaster_eg_0.wav
# full_df_ix_0485_between-eleaverton_eg_0.wav
# full_df_ix_0485_social-acather96_eg_1.wav
# full_df_ix_0486_africa-laurahale_eg_0.wav
# full_df_ix_0486_after-gonzonoir_eg_1.wav
# full_df_ix_0487_career-persian-poet-gal_eg_1.wav
# full_df_ix_0487_heavy-gorillawarfare_eg_0.wav
# full_df_ix_0488_cannot-alexkillby_eg_0.wav
# full_df_ix_0488_every-arwel-parry_eg_1.wav
# full_df_ix_0489_built-pordaria_eg_1.wav
# full_df_ix_0489_cause-macropode_eg_0.wav
# full_df_ix_0490_during-s-whistler_eg_1.wav
# full_df_ix_0490_number-emailnewberry_eg_0.wav
# full_df_ix_0491_however-s-whistler_eg_0.wav
# full_df_ix_0491_through-hassocks5489_eg_1.wav
# full_df_ix_0492_again-matthewdgonzalez_eg_0.wav
# full_df_ix_0492_during-jasonlamarche_eg_1.wav
# full_df_ix_0493_first-enviroboy_eg_1.wav
# full_df_ix_0493_south-s-whistler_eg_0.wav
# full_df_ix_0494_local-warmvoiceover_eg_1.wav
# full_df_ix_0494_series-skiasaurus_eg_0.wav
# full_df_ix_0495_church-matthewdgonzalez_eg_1.wav
# full_df_ix_0495_three-cbdroege_eg_0.wav
# full_df_ix_0496_close-matthewdgonzalez_eg_1.wav
# full_df_ix_0496_western-pordaria_eg_0.wav
# full_df_ix_0497_island-mckaysalisbury_eg_1.wav
# full_df_ix_0497_other-sethda_eg_0.wav
# full_df_ix_0498_order-alexkillby_eg_0.wav
# full_df_ix_0498_record-cbdroege_eg_1.wav
# full_df_ix_0499_making-oblong1_eg_0.wav
# full_df_ix_0499_small-alexkillby_eg_1.wav
# full_df_ix_0500_eight-caninedoubletake_eg_1.wav
# full_df_ix_0500_sound-wodup_eg_0.wav
# full_df_ix_0501_change-stifle_eg_1.wav
# full_df_ix_0501_family-alexkillby_eg_0.wav
# full_df_ix_0502_highly-leotohill_eg_0.wav
# full_df_ix_0502_which-tonyle_eg_1.wav
# full_df_ix_0503_known-alexkillby_eg_0.wav
# full_df_ix_0503_short-drkencarter_eg_1.wav
# full_df_ix_0504_after-christopherwoods_eg_1.wav
# full_df_ix_0504_twenty-the-voice-of-hassocks_eg_0.wav
# full_df_ix_0505_during-wodup_eg_0.wav
# full_df_ix_0505_english-reason-turns-rancid_eg_1.wav
# full_df_ix_0506_central-rybupsp_eg_0.wav
# full_df_ix_0506_south-mangst_eg_1.wav
# full_df_ix_0507_recent-the-voice-of-hassocks_eg_0.wav
# full_df_ix_0507_their-mikewhitcombe_eg_1.wav
# full_df_ix_0508_design-phearson_eg_0.wav
# full_df_ix_0508_series-sethda_eg_1.wav
# full_df_ix_0509_largest-the-voice-of-hassocks_eg_0.wav
# full_df_ix_0509_public-white-whirlwind_eg_1.wav
# full_df_ix_0510_island-lucas-thoms_eg_0.wav
# full_df_ix_0510_writing-theroachyjay_eg_1.wav
# full_df_ix_0511_ground-spooeekspaar_eg_0.wav
# full_df_ix_0511_which-matthewdgonzalez_eg_1.wav
# full_df_ix_0512_record-marcus-bowen_eg_1.wav
# full_df_ix_0512_state-yarnbarndarn_eg_0.wav
# full_df_ix_0513_black-divinemeaninglessness_eg_1.wav
# full_df_ix_0513_close-lordoider_eg_0.wav
# full_df_ix_0514_become-matthewdgonzalez_eg_0.wav
# full_df_ix_0514_state-0x0077be_eg_1.wav
# full_df_ix_0515_usually-pokeylicious_eg_1.wav
# full_df_ix_0515_would-matthewdgonzalez_eg_0.wav
# full_df_ix_0516_above-a-parrot_eg_1.wav
# full_df_ix_0516_appear-tonystewart14_eg_0.wav
# full_df_ix_0517_coach-peppage_eg_0.wav
# full_df_ix_0517_three-sspungy_eg_1.wav
# full_df_ix_0518_design-chemgarcia_eg_0.wav
# full_df_ix_0518_thomas-the-voice-of-hassocks_eg_1.wav
# full_df_ix_0519_civil-matthewdgonzalez_eg_0.wav
# full_df_ix_0519_which-cognate247_eg_1.wav
# full_df_ix_0520_before-demi_eg_1.wav
# full_df_ix_0520_problem-tonyle_eg_0.wav
# full_df_ix_0521_about-s-whistler_eg_0.wav
# full_df_ix_0521_could-tom-morris_eg_1.wav
# full_df_ix_0522_always-peppage_eg_0.wav
# full_df_ix_0522_science-s-whistler_eg_1.wav
# full_df_ix_0523_never-futurenjgov_eg_1.wav
# full_df_ix_0523_while-the-voice-of-hassocks_eg_0.wav
# full_df_ix_0524_british-s-whistler_eg_1.wav
# full_df_ix_0524_built-zanimum_eg_0.wav
# full_df_ix_0525_royal-matthewdgonzalez_eg_0.wav
# full_df_ix_0525_without-s-whistler_eg_1.wav
# full_df_ix_0526_brown-matthewdgonzalez_eg_1.wav
# full_df_ix_0526_stone-leotohill_eg_0.wav
# full_df_ix_0527_class-the-voice-of-hassocks_eg_1.wav
# full_df_ix_0527_version-lightdarkness_eg_0.wav
# full_df_ix_0528_david-drjacobson_eg_1.wav
# full_df_ix_0528_rather-skiasaurus_eg_0.wav
# full_df_ix_0529_career-tmalmjursson_eg_1.wav
# full_df_ix_1926_before-popularoutcast_eg_0.wav
# full_df_ix_1926_general-laura-s_eg_1.wav
# full_df_ix_1927_despite-laurascudder_eg_1.wav
# full_df_ix_1927_winter-vaslittlecrow_eg_0.wav
# full_df_ix_1928_various-dolliellama_eg_0.wav
# full_df_ix_1928_within-gorillawarfare_eg_1.wav
# full_df_ix_1929_central-popularoutcast_eg_1.wav
# full_df_ix_1929_complex-persian-poet-gal_eg_0.wav
# full_df_ix_1930_family-alanasings_eg_1.wav
# full_df_ix_1930_result-persian-poet-gal_eg_0.wav
# full_df_ix_1931_after-popularoutcast_eg_1.wav
# full_df_ix_1931_office-vaslittlecrow_eg_0.wav
# full_df_ix_1932_after-persian-poet-gal_eg_1.wav
# full_df_ix_1932_usually-dolliellama_eg_0.wav
# full_df_ix_1933_become-theexistentialist686_eg_0.wav
# full_df_ix_1933_large-thatgirltayler_eg_1.wav
# full_df_ix_1934_first-popularoutcast_eg_0.wav
# full_df_ix_1934_start-flyingtoaster_eg_1.wav
# full_df_ix_1935_being-flyingtoaster_eg_1.wav
# full_df_ix_1935_spanish-lily5lace_eg_0.wav
# full_df_ix_1936_early-laurascudder_eg_1.wav
# full_df_ix_1936_service-laura-s_eg_0.wav
# full_df_ix_1937_despite-popularoutcast_eg_0.wav
# full_df_ix_1937_those-lily5lace_eg_1.wav
# full_df_ix_1938_eight-popularoutcast_eg_0.wav
# full_df_ix_1938_however-persian-poet-gal_eg_1.wav
# full_df_ix_1939_longer-persian-poet-gal_eg_0.wav
# full_df_ix_1939_third-k9taylor_eg_1.wav
# full_df_ix_1940_before-gorillawarfare_eg_1.wav
# full_df_ix_1940_white-popularoutcast_eg_0.wav
# full_df_ix_1941_point-gorillawarfare_eg_1.wav
# full_df_ix_1941_various-fang-aili_eg_0.wav
# full_df_ix_1942_region-laura-s_eg_1.wav
# full_df_ix_1942_within-laurenpt015_eg_0.wav
# full_df_ix_1943_first-lily5lace_eg_1.wav
# full_df_ix_1943_travel-laurascudder_eg_0.wav
# full_df_ix_1944_large-1904-cc_eg_1.wav
# full_df_ix_1944_space-laura-domineau_eg_0.wav
# full_df_ix_1945_created-laura-s_eg_1.wav
# full_df_ix_1945_which-popularoutcast_eg_0.wav
# full_df_ix_1946_already-ama1016_eg_1.wav
# full_df_ix_1946_often-dolliellama_eg_0.wav
# full_df_ix_1947_early-persian-poet-gal_eg_0.wav
# full_df_ix_1947_version-ama1016_eg_1.wav
# full_df_ix_1948_group-popularoutcast_eg_0.wav
# full_df_ix_1948_married-theexistentialist686_eg_1.wav
# full_df_ix_1949_seven-persian-poet-gal_eg_0.wav
# full_df_ix_1949_twenty-laura-domineau_eg_1.wav
# full_df_ix_1950_event-flyingtoaster_eg_1.wav
# full_df_ix_1950_state-pinangjawa_eg_0.wav
# full_df_ix_1951_during-popularoutcast_eg_0.wav
# full_df_ix_1951_would-flyingtoaster_eg_1.wav

# %%
import IPython.display as ipd
print(word)
ipd.Audio(target_f_name)
# Out:
# young
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
