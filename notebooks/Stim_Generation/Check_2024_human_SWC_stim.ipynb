# %%
import numpy as np 
import librosa
import pandas as pd 
from pathlib import Path
import IPython.display as ipd
import sys 
sys.path.append('../../datasets/spatial_audio_pipeline/spatial_audio_util/')
import util_audio 
from tqdm import tqdm
# Out:
# /om2/user/imgriff/conda_envs/torch_11_cuda_11_pitch/lib/python3.9/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %% [markdown]
# # Sanity check that all files can be read for 2024 mono word recognition experiment

# %%
sound_path = Path('/om/user/imgriff/datasets/human_word_rec_SWC_2024/sounds')

list_of_sounds = list(sound_path.glob('condition*/*.wav'))

# %%
bad_fnames = []

for fname in tqdm(list_of_sounds):
    try:
        y, sr = librosa.load(fname, sr=None)
    except:
        bad_fnames.append(fname)
# Out:
# 100%|██████████| 59536/59536 [01:24<00:00, 702.02it/s]

# %%
bad_fnames
# Out:
# []
