# %%
import pandas as pd
import numpy as np

# %%
import sys 

sys.path.append('../')

# %%
f0_df = pd.read_pickle('../all_f0_ix_mapping_w_mean_var_par_file.pdpkl')

# %%
f0_df.parent_h5_file.unique()
# Out:
# array(['/om2/user/msaddler/projects/ibmHearingAid/assets/data/datasets/JSIN_v3.00/nStim_20000/2000ms/rms_0.1/noiseSNR_-10_10/stimSR_20000/reverb_none/noise_all/JSIN_all_v3/subsets/valid_RQTTZB4C3TJJVLJUWDV72TYMC7S4MNHH/JSIN_all__run_000_RQTTZB4C3TJJVLJUWDV72TYMC7S4MNHH.h5',
#        '/om2/user/msaddler/projects/ibmHearingAid/assets/data/datasets/JSIN_v3.00/nStim_20000/2000ms/rms_0.1/noiseSNR_-10_10/stimSR_20000/reverb_none/noise_all/JSIN_all_v3/subsets/valid_RQTTZB4C3TJJVLJUWDV72TYMC7S4MNHH/JSIN_all__run_001_RQTTZB4C3TJJVLJUWDV72TYMC7S4MNHH.h5',
#        '/om2/user/msaddler/projects/ibmHearingAid/assets/data/datasets/JSIN_v3.00/nStim_20000/2000ms/rms_0.1/noiseSNR_-10_10/stimSR_20000/reverb_none/noise_all/JSIN_all_v3/subsets/valid_RQTTZB4C3TJJVLJUWDV72TYMC7S4MNHH/JSIN_all__run_002_RQTTZB4C3TJJVLJUWDV72TYMC7S4MNHH.h5',
# ...

# %%
eg_file = '/om2/user/msaddler/projects/ibmHearingAid/assets/data/datasets/JSIN_v3.00/nStim_20000/2000ms/rms_0.1/noiseSNR_-10_10/stimSR_20000/reverb_none/noise_all/JSIN_all_v3/subsets/valid_RQTTZB4C3TJJVLJUWDV72TYMC7S4MNHH/JSIN_all__run_001_RQTTZB4C3TJJVLJUWDV72TYMC7S4MNHH.h5'

val_df = f0_df[f0_df.parent_h5_file == eg_file]

# %%
val_df
# Out:
#        global_ix  ix_in_parent_h5     f0_mean       f0_var  \
# 16812      16812                0  102.353081    82.255873
# 16813      16813                1  134.316029   434.371444
# 16814      16814                2  213.953238   396.365795
# 16815      16815                3  119.734713    68.679034
# 16816      16816                4  111.205615   142.702347
# ...          ...              ...         ...          ...
# 33619      33619            16807   96.525940    74.490888
# 33620      33620            16808  130.477215  1064.904470
# 33621      33621            16809  179.939499   378.071191
# 33622      33622            16810   88.261413   156.841944
# 33623      33623            16811   84.687839    59.972151
#
#                                           parent_h5_file
# 16812  /om2/user/msaddler/projects/ibmHearingAid/asse...
# 16813  /om2/user/msaddler/projects/ibmHearingAid/asse...
# 16814  /om2/user/msaddler/projects/ibmHearingAid/asse...
# ...

# %%
import h5py

val_h5 = h5py.File(eg_file, 'r')

# %%
signals = val_h5['sources']['signal']['signal']

# %%
low_f0 = signals[4]
high_f0 = signals[2]

# %%
eg_signals = signals[:100,:]

# %%
from IPython.display import Audio

# %%
Audio(out_path, rate=new_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(low_f0, rate=20000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(high_f0, rate=20000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
low_f0 = signals[16807]
high_f0 = signals[16809]

# %%
Audio(low_f0, rate=20000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(high_f0, rate=20000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
low_f0 = signals[16810]
high_f0 = signals[16808]

# %%
Audio(low_f0, rate=20000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(high_f0, rate=20000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
