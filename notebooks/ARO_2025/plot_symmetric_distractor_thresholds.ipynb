# %%
import numpy as np 
import pandas as pd
import pickle
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path 
import re 
from src import util_analysis

# %%
outfig_dest = Path('ARO_2025/')
outfig_dest.mkdir(parents=True, exist_ok=True)

# %%
import pickle 

manifest_path = "binaural_test_manifests/symmetric_distractor_conditions_neg_15_to_6_dBSNR_eval_rooms.pkl"
with open(manifest_path, "rb") as f: 
    manifest = pickle.load(f)

# %%
room_manifest = pd.read_pickle('/om2/user/msaddler/spatial_audio_pipeline/assets/brir/eval/manifest_room.pdpkl')

# %%
spkr_room_manifest = pd.read_pickle('/om2/user/msaddler/spatial_audio_pipeline/assets/brir/mit_bldg46room1004/manifest_room.pdpkl')

# %%
spkr_room_manifest
# Out:
#    head_azim      head_pos_xyz  index_room  is_outdoor  \
# 0          0   [2.3, 3.6, 0.9]           0       False
# 1          0  [3.6, 2.36, 0.9]           1       False
# 2          0  [2.36, 2.3, 0.9]           2       False
# 3          0   [2.3, 2.3, 0.9]           3       False
#
#                        material_x0                      material_x1  \
# 0  Fiberglass wall treatment, 1 in  Fiberglass wall treatment, 1 in
# 1  Fiberglass wall treatment, 1 in                Concrete, painted
# 2  Fiberglass wall treatment, 1 in  Fiberglass wall treatment, 1 in
# 3                Concrete, painted  Fiberglass wall treatment, 1 in
#
#                        material_y0                      material_y1  \
# 0  Fiberglass wall treatment, 1 in                Concrete, painted
# 1  Fiberglass wall treatment, 1 in  Fiberglass wall treatment, 1 in
# 2                Concrete, painted  Fiberglass wall treatment, 1 in
# 3  Fiberglass wall treatment, 1 in  Fiberglass wall treatment, 1 in
#
#   material_z0                                material_z1       room_dim_xyz  \
# 0    Linoleum  Acoustic tiles, 0.625", 16" below ceiling  [4.66, 5.9, 2.48]
# 1    Linoleum  Acoustic tiles, 0.625", 16" below ceiling  [5.9, 4.66, 2.48]
# 2    Linoleum  Acoustic tiles, 0.625", 16" below ceiling  [4.66, 5.9, 2.48]
# 3    Linoleum  Acoustic tiles, 0.625", 16" below ceiling  [5.9, 4.66, 2.48]
#
#          room_materials
# 0  [9, 9, 9, 2, 13, 17]
# 1  [9, 2, 9, 9, 13, 17]
# 2  [9, 9, 2, 9, 13, 17]
# 3  [2, 9, 9, 9, 13, 17]

# %%
ls /om2/user/msaddler/spatial_audio_pipeline/assets/brir/mit_bldg46room1004
# Out:
# manifest_brir.pdpkl  room0000.hdf5  room0002.hdf5
# manifest_room.pdpkl  room0001.hdf5  room0003.hdf5

# %%
room_manifest
# Out:
#    head_azim       head_pos_xyz  index_room  is_outdoor  \
# 0          0    (2.5, 2.5, 2.0)           0       False
# 1          0    (2.5, 2.5, 2.0)           1       False
# 2          0    (2.5, 2.5, 2.0)           2       False
# 3          0    (2.5, 2.5, 2.0)           3       False
# 4          0    (2.5, 2.5, 2.0)           4       False
# 5          0    (2.3, 3.6, 0.9)           5       False
# 6          0  (2.33, 2.95, 0.9)           6       False
# 7          0    (2.3, 3.6, 0.9)           7       False
# 8          0  (2.33, 2.95, 0.9)           8       False
#
#                                 material_x0  \
# 0                               (Anechoic,)
# 1  (Wood panelling on glass fiber blanket,)
# 2                                  (Brick,)
# 3        (Fiberglass wall treatment, 1 in,)
# 4                      (Concrete, painted,)
# 5        (Fiberglass wall treatment, 1 in,)
# 6        (Fiberglass wall treatment, 1 in,)
# 7        (Fiberglass wall treatment, 1 in,)
# 8        (Fiberglass wall treatment, 1 in,)
#
#                                 material_x1  \
# 0                               (Anechoic,)
# 1  (Wood panelling on glass fiber blanket,)
# 2                                  (Brick,)
# 3        (Fiberglass wall treatment, 1 in,)
# 4                      (Concrete, painted,)
# 5        (Fiberglass wall treatment, 1 in,)
# 6        (Fiberglass wall treatment, 1 in,)
# 7        (Fiberglass wall treatment, 1 in,)
# 8        (Fiberglass wall treatment, 1 in,)
#
#                                 material_y0  \
# 0                               (Anechoic,)
# 1  (Wood panelling on glass fiber blanket,)
# 2                                  (Brick,)
# 3        (Fiberglass wall treatment, 1 in,)
# 4                      (Concrete, painted,)
# 5        (Fiberglass wall treatment, 1 in,)
# 6        (Fiberglass wall treatment, 1 in,)
# 7        (Fiberglass wall treatment, 1 in,)
# 8        (Fiberglass wall treatment, 1 in,)
#
#                                 material_y1                       material_z0  \
# 0                               (Anechoic,)                       (Anechoic,)
# 1  (Wood panelling on glass fiber blanket,)  (Carpet on foam rubber padding,)
# 2                                  (Brick,)       (Wood parquet on concrete,)
# 3        (Fiberglass wall treatment, 1 in,)                       (Linoleum,)
# 4                      (Concrete, painted,)                       (Linoleum,)
# 5                      (Concrete, painted,)                       (Linoleum,)
# 6                      (Concrete, painted,)                       (Linoleum,)
# 7        (Fiberglass wall treatment, 1 in,)                       (Linoleum,)
# 8        (Fiberglass wall treatment, 1 in,)                       (Linoleum,)
#
#                                          material_z1       room_dim_xyz  \
# 0                                        (Anechoic,)    (5.0, 5.0, 4.0)
# 1  (Highly absorptive panels, 1", 16" below ceili...    (5.0, 5.0, 4.0)
# 2                (Plaster, gypsum, or lime on lath,)    (5.0, 5.0, 4.0)
# 3       (Acoustic tiles, 0.625", 16" below ceiling,)    (5.0, 5.0, 4.0)
# 4       (Acoustic tiles, 0.625", 16" below ceiling,)    (5.0, 5.0, 4.0)
# 5       (Acoustic tiles, 0.625", 16" below ceiling,)  (4.66, 5.9, 2.48)
# 6       (Acoustic tiles, 0.625", 16" below ceiling,)  (4.66, 5.9, 2.48)
# 7       (Acoustic tiles, 0.625", 16" below ceiling,)  (4.66, 5.9, 2.48)
# 8       (Acoustic tiles, 0.625", 16" below ceiling,)  (4.66, 5.9, 2.48)
#
#              room_materials
# 0  (26, 26, 26, 26, 26, 26)
# 1  (11, 11, 11, 11, 15, 20)
# 2      (1, 1, 1, 1, 12, 16)
# 3      (9, 9, 9, 9, 13, 17)
# 4      (2, 2, 2, 2, 13, 17)
# 5      (9, 9, 9, 2, 13, 17)
# 6      (9, 9, 9, 2, 13, 17)
# 7      (9, 9, 9, 9, 13, 17)
# 8      (9, 9, 9, 9, 13, 17)

# %%
# for tuple_ in room_manifest.itertuples():
#     print(tuple_)
#     break
room_material_map = {}
for row in room_manifest.itertuples():
    wall1 = row.material_x0[0].split(',')[0]
    wall2 = row.material_y1[0].split(',')[0]
    if wall1 == wall2:
        wall_str = f"{wall1} walls"
    else:
        wall_str = f"{wall1} and {wall2} walls"

    floor = row.material_z0[0].split(',')[0]
    ceiling = row.material_z1[0].split(',')[0]
    name_str = f"{wall_str} \n {floor} floor \n {ceiling} ceiling"

    if row.index_room in [5, 6]:
        name_str = 'Alternate speaker room'
    if row.index_room in [6, 8]:
        name_str += ' \n head rotated'
    else:
        head_rotated = ''
    if 'Anechoic' in name_str:
        name_str = "Anechoic"
    room_material_map[row.index_room] = name_str
# room_material_map = {row.index_room: f"{row.material_x0[0].split(',')[0]} and \n {row.material_y1[0].split(',')[0]} walls \n {row.material_z0[0].split(',')[0]} floor \n {row.material_z1[0].split(',')[0]} ceiling" for row in room_manifest.itertuples()}
# room_material_map[5] = 'standard speaker room'
room_material_map
# Out:
# {0: 'Anechoic',
#  1: 'Wood panelling on glass fiber blanket walls \n Carpet on foam rubber padding floor \n Highly absorptive panels ceiling',
#  2: 'Brick walls \n Wood parquet on concrete floor \n Plaster ceiling',
#  3: 'Fiberglass wall treatment walls \n Linoleum floor \n Acoustic tiles ceiling',
#  4: 'Concrete walls \n Linoleum floor \n Acoustic tiles ceiling',
#  5: 'Alternate speaker room',
#  6: 'Alternate speaker room \n head rotated',
#  7: 'Fiberglass wall treatment walls \n Linoleum floor \n Acoustic tiles ceiling',
#  8: 'Fiberglass wall treatment walls \n Linoleum floor \n Acoustic tiles ceiling \n head rotated'}

# %%
output_paths = list(Path(f"binaural_eval/symmetric_distractor_test/").glob("*/*room*.pkl"))

# %%
# Path to results 
# output_paths = list(Path("binaural_eval/word_task_voice_loc_cue_only_v04").glob("*.pkl")) old path for more locations

# match human pilot conditions
# model_name = 'word_task_half_co_loc_v06'
output_paths = list(Path(f"binaural_eval/symmetric_distractor_test/").glob("*/*room*.pkl"))
stim_manifest_df = pd.read_pickle('/om2/user/rphess/Auditory-Attention/final_binaural_manifest.pkl')

remap_azim = lambda azim: 360 - azim if azim > 90 else 0 - azim 

results_dfs = []

gend_map = {True:'same', False:'diff'}

for path in output_paths:
    if not any(name in str(path) for name in ['word_task_half_co_loc_v07', 'word_task_v08_control_no_attn']):
        continue
    # if 'v07' not in path.as_posix() and 'v08' not in path.as_posix():
    #     continue 
    res_dict = pickle.load(open(path, 'rb'))
    df = pd.DataFrame.from_dict(res_dict)
    df.rename(columns={"results": "accuracy"}, inplace=True)
    df['model'] = path.parent.stem
    # merge with stim manifest
    df = df.join(stim_manifest_df[['word', 'bg_word','gender', 'bg_gender']], how='outer')  
    dist_type = 'speech'
    if 'ssn' in path.stem:
        dist_type = 'noise'
    df['dist_type'] = dist_type
    if 'clean' in path.stem:
        snr = 'clean'
    else:
        snr = int(re.search('(-?\d+)_SNR', path.stem).group(0).strip('_SNR'))
    df['snr'] = snr 
    df["target_azim"], df["target_elev"] = path.stem.split('target_loc_')[1].split('_distract_loc_')[0].split('_')
    df["distractor_azim"], df["distractor_elev"] = path.stem.split('_distract_loc_')[1].split('_')[:2]
    # map azim to 0-180
    df['target_azim'] = df['target_azim'].astype(int).apply(remap_azim)
    df['distractor_azim'] = df['distractor_azim'].astype(int).apply(remap_azim)
    df['target_elev'] = df['target_elev'].astype(int)
    df['distractor_elev'] = df['distractor_elev'].astype(int)
    df['gender_cond'] = df["gender"].values == df['bg_gender'].values
    df['gender_cond'] =  df['gender_cond'].map(gend_map)
    df['room_ix'] = int(re.search('room(-?\d+)', path.stem).group(0).strip('room'))
    df['room_type'] = re.search('SNR_(.*?)_room', path.stem).group(0).split('_')[1]
    df['n_distractors'] = 1 if '1_distractor' in path.stem else 2
    
    results_dfs.append(df)

results = pd.concat(results_dfs)

# %%
results.loc[results.room_type == 'eval', 'room_str'] = results.loc[results.room_type == 'eval', 'room_ix'].map(room_material_map)

# %%
results.loc[results.room_type == 'mitb46', 'room_str'] = 'Standard speaker array'
results.loc[results.room_type == 'mitb46', 'room_ix'] = results.room_ix.unique().max() + 1

# %%
results.model.unique()
# Out:
# array(['word_task_half_co_loc_v07', nan, 'word_task_v08_control_no_attn'],
#       dtype=object)

# %%
room_material_map[results.room_ix.unique().max()] = 'Standard speaker array'
room_material_map
# Out:
# {0: 'Anechoic',
#  1: 'Wood panelling on glass fiber blanket walls \n Carpet on foam rubber padding floor \n Highly absorptive panels ceiling',
#  2: 'Brick walls \n Wood parquet on concrete floor \n Plaster ceiling',
#  3: 'Fiberglass wall treatment walls \n Linoleum floor \n Acoustic tiles ceiling',
#  4: 'Concrete walls \n Linoleum floor \n Acoustic tiles ceiling',
#  5: 'Alternate speaker room',
#  6: 'Alternate speaker room \n head rotated',
#  7: 'Fiberglass wall treatment walls \n Linoleum floor \n Acoustic tiles ceiling',
#  8: 'Fiberglass wall treatment walls \n Linoleum floor \n Acoustic tiles ceiling \n head rotated',
#  9: 'Standard speaker array',
#  11: 'Standard speaker array'}

# %%
results.dist_type.unique()
# Out:
# array(['speech', 'noise'], dtype=object)

# %%
grouped_results = results.groupby(['model', 'target_azim', 'distractor_azim', 'gender_cond', 'snr', 'dist_type', 'room_ix', 'n_distractors']).agg({'accuracy':['mean', 'sem'],
                                                                                                                     'confusions':['mean', 'sem']}).reset_index()
# flatten multiindex
grouped_results.columns = ['_'.join(col).strip() for col in grouped_results.columns.values]
# remove trailing underscore
grouped_results.columns = [col[:-1] if col[-1] == '_' else col for col in grouped_results.columns.values]

# %%
### Only need 2-distrtor data 

grouped_results = grouped_results[grouped_results.n_distractors == 2]

# %%
grouped_results.head()
# Out:
#                        model  target_azim  distractor_azim gender_cond  snr  \
# 1  word_task_half_co_loc_v07            0              -90        diff  -21
# 2  word_task_half_co_loc_v07            0              -90        diff  -21
# 4  word_task_half_co_loc_v07            0              -90        diff  -18
# 5  word_task_half_co_loc_v07            0              -90        diff  -18
# 6  word_task_half_co_loc_v07            0              -90        diff  -15
#
#   dist_type  room_ix  n_distractors  accuracy_mean  accuracy_sem  \
# 1    speech        0              2       0.136741      0.007183
# 2    speech       11              2       0.090014      0.010741
# 4    speech        0              2       0.197903      0.008329
# 5    speech       11              2       0.094233      0.010964
# 6     noise        0              2       0.155260      0.009120
#
#    confusions_mean  confusions_sem
# 1         0.044124        0.004293
# 2         0.023910        0.005733
# 4         0.028834        0.003498
# 5         0.012658        0.004196
# 6         0.002535        0.001266

# %%
### Byrne et al. 2023 data 

byrne_data = np.array([-0.09484242924828479, 0.4982925897160886,
                        5.013827763189802, -3.951329561004476,
                        10.05543433148005, -10.226709567661526,
                        19.95734556258245, -13.644653196411767,
                        39.96515321490358, -15.760526975438765,
                        0.022518913010429742, -11.306631162395057,
                        5.0401272236399315, -11.078483342990165,
                        10.065132257521036, -12.854847524768747,
                        19.96030425188309, -14.446457996885155,
                        39.8901997526207, -15.448138696779548]).reshape(-1, 2)
                        
byrne_data = pd.DataFrame({'distractor_azim':byrne_data[:,0], 'threshold_snr':byrne_data[:,1]})
byrne_data['dist_type'] = ["speech"] * 5 + ["noise"] * 5 
byrne_data['distractor_azim'] = byrne_data['distractor_azim'].astype(int).abs()
byrne_data
# Out:
#    distractor_azim  threshold_snr dist_type
# 0                0       0.498293    speech
# 1                5      -3.951330    speech
# 2               10     -10.226710    speech
# 3               19     -13.644653    speech
# 4               39     -15.760527    speech
# 5                0     -11.306631     noise
# 6                5     -11.078483     noise
# 7               10     -12.854848     noise
# 8               19     -14.446458     noise
# 9               39     -15.448139     noise

# %%
grouped_results.columns
# Out:
# Index(['model', 'target_azim', 'distractor_azim', 'gender_cond', 'snr',
#        'dist_type', 'room_ix', 'n_distractors', 'accuracy_mean',
#        'accuracy_sem', 'confusions_mean', 'confusions_sem'],
#       dtype='object')

# %%
# outfig_dest = Path('CCN_2024/figures')
# outfig_dest.mkdir(parents=True, exist_ok=True)

# %%
model_thresholds_df
# Out:
#                             model  distractor_azim  threshold_snr
# 0  Feature-based\nattention model                0      -1.341838
# 1  Feature-based\nattention model                5      -4.223229
# 2  Feature-based\nattention model               10      -6.185967
# 3  Feature-based\nattention model               20      -8.602895
# 4  Feature-based\nattention model               30      -8.984583
# 5  Feature-based\nattention model               40      -9.713865

# %%
wanted_models = [ 'word_task_half_co_loc_v07', 'word_task_v08_control_no_attn']

model_name_dict= { 'word_task_half_co_loc_v07': "Feature-based\nattention model", 
                'word_task_v08_control_no_attn': "Baseline CNN"}

human_str = "Human\n(Byrne et al., 2023)"

model_to_plot = grouped_results[(grouped_results.model.isin(wanted_models)) & (grouped_results.room_ix.isin([0])) & (grouped_results.n_distractors == 2)].copy() #& (grouped_results.target_azim == 'center')]
model_to_plot['distractor_azim'] = model_to_plot['distractor_azim'].astype(int).abs()
model_to_plot = model_to_plot[model_to_plot.distractor_azim <= 40]

# get threshold for each target azimuth and dist_type
model_thresholds = []
for (model, azim), group in model_to_plot.groupby(['model', 'distractor_azim']):
    thresh, fit_popt, _ = util_analysis.estimate_thresholds(group.snr.values, group.accuracy_mean.values, threshold_value='half', bounds_from_data=True)
    if np.isnan(thresh):
        print(f"Threshold is nan for azim {azim} with model {model}")
    model_thresholds.append({'model': model_name_dict[model], 'distractor_azim': azim, 'threshold_snr':thresh}) #  'gender_cond':gend_cond,


model_thresholds_df = pd.DataFrame(model_thresholds)


# add byrne data to model_to_plot
byrne_data['model'] = human_str
data_to_plot = pd.concat([model_thresholds_df, byrne_data], axis=0)
data_to_plot = data_to_plot[data_to_plot.dist_type == 'speech']
# make a palette for noise and speech where speech is black and noise is blue
# palette = {'speech':'k', 'noise':'r'}

cmap = sns.color_palette("viridis", n_colors=len(wanted_models))
palette = dict(zip(model_name_dict.values(), cmap))

palette[human_str] = 'k'

# col_order = [human_str, 'Model']
sns.set_style('ticks')
# plot 

g = sns.relplot(data=data_to_plot, x='distractor_azim', y='threshold_snr',
              #  col = 'model',# col_order=col_order,
                hue='model', palette=palette, 
                # alpha=0.5,
                style='model', style_order=[human_str] + list(model_name_dict.values()),
                kind='line', linewidth=3, zorder=5, legend=True,
                facet_kws={'sharey':False},
                errorbar=('se', 2), height=2.25, aspect=1.25, )

g.axes[0][0].set_title("Spatial release from masking")
g.set_axis_labels("Distractor azimuth ($\degree$, +/-)", "Threshold SNR (dB)")
g.set_titles("{col_name}")

# plt.suptitle("Symmetric distractor positions", y=1.05)
g.set(yticks=np.arange(-18,  7, 6))
# g.legend.remove()

g._legend.set_title("")
 
# move  legend of g to the right
# g._legend.set_bbox_to_anchor([0.7, 0.75])

x_tick_locs = np.sort(model_to_plot.distractor_azim.unique())
x_tick_labels = [str(x) for x in x_tick_locs]
for ax in g.axes.flat:
    labels = ax.get_xticklabels() # get x labels
    ax.set_xticks(ticks=x_tick_locs) # set new labels
    ax.set_xticklabels(labels=x_tick_labels)

ratio = 1 
for ax in g.axes.flat:
    xleft, xright = ax.get_xlim()
    ybottom, ytop = ax.get_ylim()
    ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)
    for axis in ['bottom','left']:
        ax.spines[axis].set_linewidth(1.5)
# save figure as svg 
# plt.tight_layout()
# plt.savefig(outfig_dest/'symmetric_distractor_thresholds.pdf', transparent=True, bbox_inches='tight')

# %%
data_to_plot
# Out:
#                             model  distractor_azim  threshold_snr dist_type
# 0  Feature-based\nattention model                0      -1.341838       NaN
# 1  Feature-based\nattention model                5      -4.223229       NaN
# 2  Feature-based\nattention model               10      -6.185967       NaN
# 3  Feature-based\nattention model               20      -8.602895       NaN
# 4  Feature-based\nattention model               30      -8.984583       NaN
# 5  Feature-based\nattention model               40      -9.713865       NaN
# 0     Human\n(Byrne et al., 2023)                0       0.498293    speech
# 1     Human\n(Byrne et al., 2023)                5      -3.951330    speech
# 2     Human\n(Byrne et al., 2023)               10     -10.226710    speech
# 3     Human\n(Byrne et al., 2023)               19     -13.644653    speech
# 4     Human\n(Byrne et al., 2023)               39     -15.760527    speech
# 5     Human\n(Byrne et al., 2023)                0     -11.306631     noise
# 6     Human\n(Byrne et al., 2023)                5     -11.078483     noise
# 7     Human\n(Byrne et al., 2023)               10     -12.854848     noise
# 8     Human\n(Byrne et al., 2023)               19     -14.446458     noise
# 9     Human\n(Byrne et al., 2023)               39     -15.448139     noise

# %%
grouped_results
# Out:
#                               model  target_azim  distractor_azim gender_cond  \
# 1         word_task_half_co_loc_v07            0              -90        diff
# 2         word_task_half_co_loc_v07            0              -90        diff
# 4         word_task_half_co_loc_v07            0              -90        diff
# 5         word_task_half_co_loc_v07            0              -90        diff
# 6         word_task_half_co_loc_v07            0              -90        diff
# ...                             ...          ...              ...         ...
# 4323  word_task_v08_control_no_attn            0                0        same
# 4324  word_task_v08_control_no_attn            0                0        same
# 4325  word_task_v08_control_no_attn            0                0        same
# 4326  word_task_v08_control_no_attn            0                0        same
# 4327  word_task_v08_control_no_attn            0                0        same
#
#       snr dist_type  room_ix  n_distractors  accuracy_mean  accuracy_sem  \
# 1     -21    speech        0              2       0.136741      0.007183
# 2     -21    speech       11              2       0.090014      0.010741
# 4     -18    speech        0              2       0.197903      0.008329
# 5     -18    speech       11              2       0.094233      0.010964
# 6     -15     noise        0              2       0.155260      0.009120
# ...   ...       ...      ...            ...            ...           ...
# 4323   -6    speech        0              2       0.112801      0.007966
# 4324   -3    speech        0              2       0.192649      0.009931
# 4325    0    speech        0              2       0.301648      0.011558
# 4326    3    speech        0              2       0.410646      0.012388
# 4327    6    speech        0              2       0.503802      0.012590
#
#       confusions_mean  confusions_sem
# 1            0.044124        0.004293
# 2            0.023910        0.005733
# 4            0.028834        0.003498
# 5            0.012658        0.004196
# 6            0.002535        0.001266
# ...               ...             ...
# 4323         0.310520        0.011652
# 4324         0.227503        0.010557
# 4325         0.160963        0.009254
# 4326         0.122307        0.008251
# 4327         0.074778        0.006624
#
# [2908 rows x 12 columns]

# %%
grouped_results

# %%
wanted_models = [ 'word_task_half_co_loc_v07']

model_name_dict= { 'word_task_half_co_loc_v07': "Feature-based\nattention model", }
                # 'word_task_v08_control_no_attn': "Baseline CNN"}

human_str = "Human\n(Byrne et al., 2023)"

model_to_plot = grouped_results[(grouped_results.model.isin(wanted_models)) & (grouped_results.room_ix.isin([0])) & (grouped_results.n_distractors == 2) & (grouped_results.dist_type == 'speech')].copy() #& (grouped_results.target_azim == 'center')]
model_to_plot['distractor_azim'] = model_to_plot['distractor_azim'].astype(int).abs()
model_to_plot = model_to_plot[model_to_plot.distractor_azim <= 40]

# get threshold for each target azimuth and dist_type
model_thresholds = []
for (model, azim), group in model_to_plot.groupby(['model', 'distractor_azim']):
    thresh, fit_popt, _ = util_analysis.estimate_thresholds(group.snr.values, group.accuracy_mean.values, threshold_value='half', bounds_from_data=True)
    if np.isnan(thresh):
        print(f"Threshold is nan for azim {azim} with model {model}")
    model_thresholds.append({'model': model_name_dict[model], 'distractor_azim': azim, 'threshold_snr':thresh}) #  'gender_cond':gend_cond,


model_thresholds_df = pd.DataFrame(model_thresholds)


# add byrne data to model_to_plot
byrne_data['model'] = human_str
byrne_data = byrne_data[byrne_data.dist_type == 'speech']
data_to_plot = pd.concat([model_thresholds_df, byrne_data], axis=0)
# make a palette for noise and speech where speech is black and noise is blue
# palette = {'speech':'k', 'noise':'r'}

cmap = sns.color_palette("viridis", n_colors=len(wanted_models)+1)
palette = dict(zip(model_name_dict.values(), cmap))

palette[human_str] = 'k'

# col_order = [human_str, 'Model']
sns.set_style('ticks')
# plot 

g = sns.relplot(data=data_to_plot, x='distractor_azim', y='threshold_snr',
              #  col = 'model',# col_order=col_order,
                hue='model', palette=palette, 
                # alpha=0.5,
                style='model', style_order=[human_str] + list(model_name_dict.values()),
                kind='line', linewidth=3, zorder=5, legend=True,
                facet_kws={'sharey':False},
                errorbar=('se', 2), height=2.25, aspect=1.25, )

g.axes[0][0].set_title("Spatial release from masking")
g.set_axis_labels("Distractor azimuth ($\degree$, +/-)", "Threshold SNR (dB)")
g.set_titles("{col_name}")

# plt.suptitle("Symmetric distractor positions", y=1.05)
g.set(yticks=np.arange(-18,  7, 6))
# g.set(xticks=np.arange(0,  7, 6))
g.legend.remove()

# g._legend.set_title("")
 
# move  legend of g to the right
# g._legend.set_bbox_to_anchor([0.7, 0.75])

x_tick_locs = np.sort(model_to_plot.distractor_azim.unique())
x_tick_labels = [str(x) for x in x_tick_locs]
for ax in g.axes.flat:
    labels = ax.get_xticklabels() # get x labels
    ax.set_xticks(ticks=x_tick_locs) # set new labels
    ax.set_xticklabels(labels=x_tick_labels)

ratio = 1 
for ax in g.axes.flat:
    xleft, xright = ax.get_xlim()
    ybottom, ytop = ax.get_ylim()
    ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)
    for axis in ['bottom','left']:
        ax.spines[axis].set_linewidth(1.5)
# save figure as svg 
# plt.tight_layout()
# plt.savefig(outfig_dest/'symmetric_distractor_thresholds.pdf', transparent=True, bbox_inches='tight')

# %%
x_tick_locs
# Out:
# array([ 0,  5, 10, 20, 30, 40])

# %%
wanted_models = [ 'word_task_half_co_loc_v07']

model_name_dict= { 'word_task_half_co_loc_v07': "Feature-based\nattention model", }
                # 'word_task_v08_control_no_attn': "Baseline CNN"}

human_str = "Human\n(Byrne et al., 2023)"

model_to_plot = grouped_results[(grouped_results.model.isin(wanted_models)) & (grouped_results.room_ix.isin([0])) & (grouped_results.n_distractors == 2) & (grouped_results.dist_type == 'speech')].copy() #& (grouped_results.target_azim == 'center')]
model_to_plot['distractor_azim'] = model_to_plot['distractor_azim'].astype(int).abs()
model_to_plot = model_to_plot[model_to_plot.distractor_azim <= 40]

# get threshold for each target azimuth and dist_type
model_thresholds = []
for (model, azim), group in model_to_plot.groupby(['model', 'distractor_azim']):
    thresh, fit_popt, _ = util_analysis.estimate_thresholds(group.snr.values, group.accuracy_mean.values, threshold_value='half', bounds_from_data=True)
    if np.isnan(thresh):
        print(f"Threshold is nan for azim {azim} with model {model}")
    model_thresholds.append({'model': model_name_dict[model], 'distractor_azim': azim, 'threshold_snr':thresh}) #  'gender_cond':gend_cond,


model_thresholds_df = pd.DataFrame(model_thresholds)


# add byrne data to model_to_plot
byrne_data['model'] = human_str
byrne_data = byrne_data[byrne_data.dist_type == 'speech']
data_to_plot = pd.concat([model_thresholds_df, byrne_data], axis=0)
# make a palette for noise and speech where speech is black and noise is blue
# palette = {'speech':'k', 'noise':'r'}

cmap = sns.color_palette("viridis", n_colors=len(wanted_models)+1)
palette = dict(zip(model_name_dict.values(), cmap))

palette[human_str] = 'k'

# col_order = [human_str, 'Model']
sns.set_style('ticks')
# plot 

g = sns.relplot(data=data_to_plot[data_to_plot.model == human_str], x='distractor_azim', y='threshold_snr',
              #  col = 'model',# col_order=col_order,
                hue='model', palette=palette, 
                # alpha=0.5,
                style='model', style_order=[human_str] + list(model_name_dict.values()),
                kind='line', linewidth=3, zorder=5, legend=True,
                facet_kws={'sharey':False},
                errorbar=('se', 2), height=2.25, aspect=1.25, )

g.axes[0][0].set_title("Spatial release from masking")
g.set_axis_labels("Distractor azimuth ($\degree$, +/-)", "Threshold SNR (dB)")
g.set_titles("{col_name}")

# plt.suptitle("Symmetric distractor positions", y=1.05)
g.set(yticks=np.arange(-18,  7, 6))
g.legend.remove()

# g._legend.set_title("")
 
# move  legend of g to the right
# g._legend.set_bbox_to_anchor([0.7, 0.75])

# x_tick_locs = np.sort(model_to_plot.distractor_azim.unique())
# x_tick_labels = [str(x) for x in x_tick_locs]
for ax in g.axes.flat:
    labels = ax.get_xticklabels() # get x labels
    ax.set_xticks(ticks=x_tick_locs) # set new labels
    ax.set_xticklabels(labels=x_tick_labels)

ratio = 1 
for ax in g.axes.flat:
    xleft, xright = ax.get_xlim()
    ybottom, ytop = ax.get_ylim()
    ax.set_aspect(abs((xright-xleft)/(ybottom-ytop))*ratio)
    for axis in ['bottom','left']:
        ax.spines[axis].set_linewidth(1.5)
# save figure as svg 
# plt.tight_layout()
# plt.savefig(outfig_dest/'symmetric_distractor_thresholds_human_only.pdf', transparent=True, bbox_inches='tight')
