# %%
import numpy as np 
import pandas as pd
import pickle
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
output_paths = list(Path('saddler_eval').glob('**/*.pkl'))
# output_paths

# %%
path.stem.split(path.parent.name)[-1].split('_')[-3]
# Out:
# '3'

# %%
results_dfs = []
for path in output_paths:
    res_dict = pickle.load(open(path, 'rb'))
    # reformat dict
    record = {}
    record['accuracy'] = res_dict['acc']
    record['std_error'] = res_dict['std_err']
    record['model'] = path.parent.name
    #parts of name 
    parts = path.stem.split(path.parent.name)[-1].split('_')        
    record['condition'] = parts[1]
    if 'clean' in path.stem:
        record['snr'] = np.inf
    else:
        record['snr'] = int(parts[-3])

    df = pd.DataFrame.from_records([record])
    results_dfs.append(df)
results = pd.concat(results_dfs)

# %%
results
# Out:
#    accuracy  std_error                                              model  \
# 0  0.367021   0.024890  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.742021   0.022594  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.643617   0.024732  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.478723   0.025797  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.771277   0.021689  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.789894   0.021037  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.063830   0.012623  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.523936   0.025790  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.316489   0.024018  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.148936   0.018385  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.627660   0.024964  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.715426   0.023300  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.797872   0.020738  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.170213   0.019407  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.630319   0.024927  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.539894   0.025738  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.343085   0.024515  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.704787   0.023555  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.760638   0.022034  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.271277   0.022960  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.611702   0.025167  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.502660   0.025820  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.377660   0.025035  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.694149   0.023794  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.768617   0.021777  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.297872   0.023616  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.712766   0.023366  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.595745   0.025342  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.449468   0.025688  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.771277   0.021689  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.805851   0.020426  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.156915   0.018782  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.617021   0.025103  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.489362   0.025814  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.287234   0.023366  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.715426   0.023300  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 0  0.773936   0.021600  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
#
#     condition   snr
# 0    audioset -12.0
# 0    audioset  -3.0
# 0    audioset  -6.0
# 0    audioset  -9.0
# 0    audioset   0.0
# 0    audioset   3.0
# 0      babble -12.0
# 0      babble  -3.0
# 0      babble  -6.0
# 0      babble  -9.0
# 0      babble   0.0
# 0      babble   3.0
# 0       clean   inf
# 0        ieee -12.0
# 0        ieee  -3.0
# 0        ieee  -6.0
# 0        ieee  -9.0
# 0        ieee   0.0
# 0        ieee   3.0
# 0   modulated -12.0
# 0   modulated  -3.0
# 0   modulated  -6.0
# 0   modulated  -9.0
# 0   modulated   0.0
# 0   modulated   3.0
# 0       music -12.0
# 0       music  -3.0
# 0       music  -6.0
# 0       music  -9.0
# 0       music   0.0
# 0       music   3.0
# 0  stationary -12.0
# 0  stationary  -3.0
# 0  stationary  -6.0
# 0  stationary  -9.0
# 0  stationary   0.0
# 0  stationary   3.0

# %%
human_df = pd.read_csv('/mindhive/mcdermott/www/msaddler/msjspsych/experiment_word_recognition/data/human_experiment_v00/combined_results.csv')

# %%
## group by

# %%
# fg_manifest['word'].map(word_2_class)

test_condition_dict = {'music':"background_musdb18hq",
                       "babble":"background_cv08talkerbabble",
                       "stationary": "background_issnstationary",
                       "modulated": "background_issnfestenplomp",
                       "audioset": "background_audioset",
                       "ieee": "background_ieeeaaspcasa",
                       "clean": "background_SILENCE"}

path_to_cond = {v:k for k,v in test_condition_dict.items()}

# %%
human_df.head()
# Out:
#           background_condition  correct/count  correct/mean  correct/sum  \
# 0           background_SILENCE             15      0.866667         13.0
# 1  background_cv08talkerbabble             14      0.000000          0.0
# 2  background_cv08talkerbabble             14      0.000000          0.0
# 3  background_cv08talkerbabble             14      0.214286          3.0
# 4  background_cv08talkerbabble             14      0.500000          7.0
#
#    participant_age participant_gender  participant_hearing_loss  \
# 0               32               Male                     False
# 1               32               Male                     False
# 2               32               Male                     False
# 3               32               Male                     False
# 4               32               Male                     False
#
#              participant_id  snr
# 0  544e94c4fdf99b50bd30726c  inf
# 1  544e94c4fdf99b50bd30726c -9.0
# 2  544e94c4fdf99b50bd30726c -6.0
# 3  544e94c4fdf99b50bd30726c -3.0
# 4  544e94c4fdf99b50bd30726c  0.0

# %%
## group human_df by participant_id, background_background, and snr, and compute mean accuracy and std error for correct/mean column

human_results = human_df.groupby(['background_condition', 'snr']).agg({'correct/mean': ['mean', 'sem']}).reset_index()

human_results.columns = ['background_condition', 'snr', 'accuracy', 'std_error']

human_results['model'] = 'human'

human_results['condition'] = human_results['background_condition'].map(path_to_cond)

# %%
human_results
# Out:
#            background_condition  snr  accuracy  std_error  model   condition
# 0            background_SILENCE  inf  0.788693   0.016813  human       clean
# 1   background_cv08talkerbabble -9.0  0.023403   0.004757  human      babble
# 2   background_cv08talkerbabble -6.0  0.054161   0.007746  human      babble
# 3   background_cv08talkerbabble -3.0  0.168683   0.012997  human      babble
# 4   background_cv08talkerbabble  0.0  0.376188   0.015179  human      babble
# 5   background_cv08talkerbabble  3.0  0.561132   0.018973  human      babble
# 6       background_ieeeaaspcasa -9.0  0.155742   0.011367  human        ieee
# 7       background_ieeeaaspcasa -6.0  0.260333   0.015056  human        ieee
# 8       background_ieeeaaspcasa -3.0  0.418723   0.016392  human        ieee
# 9       background_ieeeaaspcasa  0.0  0.573885   0.018567  human        ieee
# 10      background_ieeeaaspcasa  3.0  0.625999   0.020846  human        ieee
# 11   background_issnfestenplomp -9.0  0.296910   0.016533  human   modulated
# 12   background_issnfestenplomp -6.0  0.398023   0.019122  human   modulated
# 13   background_issnfestenplomp -3.0  0.516911   0.019600  human   modulated
# 14   background_issnfestenplomp  0.0  0.628448   0.022290  human   modulated
# 15   background_issnfestenplomp  3.0  0.705900   0.019408  human   modulated
# 16    background_issnstationary -9.0  0.039873   0.006876  human  stationary
# 17    background_issnstationary -6.0  0.184545   0.014542  human  stationary
# 18    background_issnstationary -3.0  0.383644   0.019806  human  stationary
# 19    background_issnstationary  0.0  0.607549   0.017588  human  stationary
# 20    background_issnstationary  3.0  0.713975   0.015740  human  stationary
# 21         background_musdb18hq -9.0  0.333188   0.016636  human       music
# 22         background_musdb18hq -6.0  0.423887   0.018321  human       music
# 23         background_musdb18hq -3.0  0.564174   0.020741  human       music
# 24         background_musdb18hq  0.0  0.648603   0.019850  human       music
# 25         background_musdb18hq  3.0  0.695017   0.017726  human       music

# %%
combined = pd.concat([results, human_results], axis=0, ignore_index=True)

# %%
combined
# Out:
#     accuracy  std_error                                              model  \
# 0   0.367021   0.024890  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 1   0.742021   0.022594  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 2   0.643617   0.024732  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 3   0.478723   0.025797  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# 4   0.771277   0.021689  attn_cue_lr_1e-4_bs_64_constrained_slope_multi...
# ..       ...        ...                                                ...
# 58  0.333188   0.016636                                              human
# 59  0.423887   0.018321                                              human
# 60  0.564174   0.020741                                              human
# 61  0.648603   0.019850                                              human
# 62  0.695017   0.017726                                              human
#
#    condition   snr  background_condition
# 0   audioset -12.0                   NaN
# 1   audioset  -3.0                   NaN
# 2   audioset  -6.0                   NaN
# 3   audioset  -9.0                   NaN
# 4   audioset   0.0                   NaN
# ..       ...   ...                   ...
# 58     music  -9.0  background_musdb18hq
# 59     music  -6.0  background_musdb18hq
# 60     music  -3.0  background_musdb18hq
# 61     music   0.0  background_musdb18hq
# 62     music   3.0  background_musdb18hq
#
# [63 rows x 6 columns]

# %%
# replace inf in snr with 6 
combined['snr'] = combined['snr'].replace(np.inf, 6)

# replace ieee with natural scene
combined['condition'] = combined['condition'].replace('ieee', 'natural scene')
combined.model.unique()
# Out:
# array(['attn_cue_lr_1e-4_bs_64_constrained_slope_multi_distractor',
#        'human'], dtype=object)

# %%
to_plot = combined[(combined.condition!='audioset') & (combined.snr > -12)]
palette = dict(zip(to_plot.condition.unique(), sns.color_palette(n_colors= len(to_plot.condition.unique()), as_cmap=True)))

hue_order = ['clean', 'babble',  'stationary', 'modulated', 'music', 'natural scene', ]
# add markers to relplot
# plt.figure(figsize=(2,2))
g = sns.relplot(data=to_plot, x='snr', y='accuracy', hue='condition', hue_order=hue_order, col="model",
                # style='model', style_order=['human', "attn_cue_lr_1e-4_bs_64_constrained_slope_multi_distractor"],
                  kind='line', marker='*', palette=palette, height=4, aspect=1)
# g.map(plt.errorbar, "snr", "accuracy", "std_error", marker=None, ls='none')


# iterate through each facet of the facetgrid
for model, ax in g.axes_dict.items():
    # select the data for the facet
    data = to_plot[to_plot['model'].eq(model)]
    # select the data for each hue group
    for group, selected in data.groupby('condition'):
        # plot the errorbar with the correct color for each group 
        ax.errorbar(data=selected, x="snr", y="accuracy", yerr="std_error", color=palette[group], marker=None, ls='none' )

x_tick_locs = to_plot.snr.unique()
x_tick_labels = [str(x) for x in x_tick_locs]
x_tick_labels[-1] = 'inf'
for ax in g.axes.flat:
    labels = ax.get_xticklabels() # get x labels
    ax.set_xticks(ticks=x_tick_locs) # set new labels
    ax.set_xticklabels(labels=x_tick_labels)
plt.ylim(0,.9)
g.axes.flat[0].set_ylabel('Accuracy')
g.axes.flat[1].set_ylabel('')
g.axes.flat[0].set_xlabel('SNR (dB)')
g.axes.flat[1].set_xlabel('SNR (dB)')
g.axes.flat[0].set_title('Model')
g.axes.flat[1].set_title('Human')


# plt.tight_layout()
# Out:
# Text(0.5, 1.0, 'Human')

# %%
hue_order_model = ['clean', 'babble', 'ieee', 'modulated', 'stationary', 'music']
sns.catplot(data=results[results.condition != 'audioset'], x='snr', y='accuracy', hue='condition', hue_order=hue_order_model, kind='point')
