# %%
import logging
import sys
sys.path.append('../')
import torch
import torchaudio
from src.giga_las_lightning import LASModule
import yaml
from tqdm.notebook import tqdm

from collections import namedtuple

# %%
config_path = '../config/giga/giga_word_las_train_base.yaml'

config = yaml.load(open(config_path, 'r'), Loader=yaml.FullLoader)

# %%
config['n_jobs'] = 10

# %%
# map_location = {'cuda:0':'cpu'}
model = LASModule(config)
# Out:
# Using custom data configuration default-6ff8619ed1bf5008
# Reusing dataset csv (/home/imgriff/.cache/huggingface/datasets/csv/default-6ff8619ed1bf5008/0.0.0/6b9057d9e23d9d8a2f05b985917a0da84d70c5dae3d22ddd8a3f22fb01c69d9e)
# Using custom data configuration default-57731ec938d8e394
# Reusing dataset csv (/home/imgriff/.cache/huggingface/datasets/csv/default-57731ec938d8e394/0.0.0/6b9057d9e23d9d8a2f05b985917a0da84d70c5dae3d22ddd8a3f22fb01c69d9e)

# %%
dataloader = model.train_dataloader()

# %%
model = model.eval().cuda()


# y_pred = []
# y_true = []

with torch.no_grad():
    for idx, batch in enumerate(tqdm(dataloader)):
        loss = model.training_step(batch, idx)
        if idx == 100:
            break
# Out:
#   0%|          | 0/8282987 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <module>
#       4 # y_pred = []
#       5 # y_true = []
#       7 with torch.no_grad():
# ----> 8     for idx, batch in enumerate(tqdm(dataloader)):
#       9         loss = model.training_step(batch, idx)
#      10         if idx == 100:
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/torchaudio_11/lib/python3.9/site-packages/tqdm/notebook.py:257, in tqdm_notebook.__iter__(self)
#     255 def __iter__(self):
#     256     try:
# --> 257         for obj in super(tqdm_notebook, self).__iter__():
#     258             # return super(tqdm...) will not catch exception
#     259             yield obj
#     260     # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/torchaudio_11/lib/python3.9/site-packages/tqdm/std.py:1180, in tqdm.__iter__(self)
#    1177 time = self._time
#    1179 try:
# -> 1180     for obj in iterable:
#    1181         yield obj
#    1182         # Update and possibly print the progressbar.
#    1183         # Note: does not call self.update(1) for speed optimisation.
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/torchaudio_11/lib/python3.9/site-packages/torch/utils/data/dataloader.py:530, in _BaseDataLoaderIter.__next__(self)
#     528 if self._sampler_iter is None:
#     529     self._reset()
# --> 530 data = self._next_data()
#     531 self._num_yielded += 1
#     532 if self._dataset_kind == _DatasetKind.Iterable and \
#     533         self._IterableDataset_len_called is not None and \
#     534         self._num_yielded > self._IterableDataset_len_called:
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/torchaudio_11/lib/python3.9/site-packages/torch/utils/data/dataloader.py:1207, in _MultiProcessingDataLoaderIter._next_data(self)
#    1204     return self._process_data(data)
#    1206 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1207 idx, data = self._get_data()
#    1208 self._tasks_outstanding -= 1
#    1209 if self._dataset_kind == _DatasetKind.Iterable:
#    1210     # Check for _IterableDatasetStopIteration
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/torchaudio_11/lib/python3.9/site-packages/torch/utils/data/dataloader.py:1163, in _MultiProcessingDataLoaderIter._get_data(self)
#    1161 elif self._pin_memory:
#    1162     while self._pin_memory_thread.is_alive():
# -> 1163         success, data = self._try_get_data()
#    1164         if success:
#    1165             return data
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/torchaudio_11/lib/python3.9/site-packages/torch/utils/data/dataloader.py:1011, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#     998 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#     999     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1000     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1008     # Returns a 2-tuple:
#    1009     #   (bool: whether successfully get data, any: data if successful else None)
#    1010     try:
# -> 1011         data = self._data_queue.get(timeout=timeout)
#    1012         return (True, data)
#    1013     except Exception as e:
#    1014         # At timeout and error, we manually check whether any worker has
#    1015         # failed. Note that this is the only mechanism for Windows to detect
#    1016         # worker failures.
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/torchaudio_11/lib/python3.9/queue.py:180, in Queue.get(self, block, timeout)
#     178         if remaining <= 0.0:
#     179             raise Empty
# --> 180         self.not_empty.wait(remaining)
#     181 item = self._get()
#     182 self.not_full.notify()
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/torchaudio_11/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
loss
# Out:
# tensor(9.2110, device='cuda:0')

# %%
model
# Out:
# LASModule(
#   (model): ASR(
#     (encoder): Encoder(
#       (layers): ModuleList(
#         (0): VGGExtractor(
#           (extractor): Sequential(
#             (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): ReLU()
#             (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (3): ReLU()
#             (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#             (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (6): ReLU()
#             (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (8): ReLU()
#             (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           )
#         )
#         (1): RNNLayer(
#           (layer): LSTM(1280, 512, batch_first=True)
#           (pj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (2): RNNLayer(
#           (layer): LSTM(512, 512, batch_first=True)
#           (pj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (3): RNNLayer(
#           (layer): LSTM(512, 512, batch_first=True)
#           (pj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (4): RNNLayer(
#           (layer): LSTM(512, 512, batch_first=True)
#           (pj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (5): RNNLayer(
#           (layer): LSTM(512, 512, batch_first=True)
#           (pj): Linear(in_features=512, out_features=512, bias=True)
#         )
#       )
#     )
#     (pre_embed): Embedding(10003, 512)
#     (embed_drop): Dropout(p=0.0, inplace=False)
#     (decoder): Decoder(
#       (layers): LSTM(1024, 512, batch_first=True)
#       (char_trans): Linear(in_features=512, out_features=10003, bias=True)
#       (final_dropout): Dropout(p=0, inplace=False)
#     )
#     (attention): Attention(
#       (proj_q): Linear(in_features=512, out_features=300, bias=True)
#       (proj_k): Linear(in_features=512, out_features=300, bias=True)
#       (att_layer): LocationAwareAttention(
#         (softmax): Softmax(dim=-1)
#         (loc_conv): Conv1d(1, 10, kernel_size=(201,), stride=(1,), padding=(100,), bias=False)
#         (loc_proj): Linear(in_features=10, out_features=300, bias=False)
#         (gen_energy): Linear(in_features=300, out_features=1, bias=True)
#       )
#     )
#   )
#   (seq_loss): CrossEntropyLoss()
#   (ctc_loss): CTCLoss()
# )
