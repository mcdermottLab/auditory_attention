# %%
# import both models with same random parameters and make sure output for random input is the same
import torch
import importlib
import yaml
import src.binaural_attention_model as bm
import src.spatial_attn_architecture as sm

random_input = torch.rand([1, 2, 40, 20000])

# %%
importlib.reload(bm)
importlib.reload(sm)
bin_config = yaml.load(open('SpatialAudio/reference/binaural_attention_config.yml', 'r'), Loader=yaml.FullLoader)
bin_model = bm.BinauralAttentionCNN(**bin_config['model'])

modular_config = yaml.load(open('config/binaural_attn/Spatial_Task_Config.yml', 'r'), Loader=yaml.FullLoader)
modular_model = sm.CNN2DExtractor(**modular_config['model'])
# Out:
# num_classes={'num_words': 998}
# Model performing word task
# num_classes={'num_words': 998}
# Model performing word task

# %%
for param in bin_model.parameters():
    param.data = torch.nn.parameter.Parameter(torch.ones_like(param) * .01)

for param in modular_model.parameters():
    param.data = torch.nn.parameter.Parameter(torch.ones_like(param) * .01)

# %%
bin_out = bin_model(random_input, random_input)

# %%
torch_out = modular_model(random_input, random_input)

# %%
bin_out
# Out:
# tensor([[0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001,
#          0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001,
#          0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001,
#          0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001,
#          0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001,
#          0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001,
#          0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001,
#          0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001,
#          0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001,
#          0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001,
#          0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001,
#          0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001,
# ...
