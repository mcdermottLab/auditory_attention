# %%
import numpy as np 
import pandas as pd
import dask.dataframe as dd

# %%
8e6
# Out:
# 8000000.0

# %%
dct = {'col1':{str(ix):ix for ix in range(int(8e6))}}

# %%
df = pd.DataFrame.from_dict(dct)

# %%
ddf = dd.read_csv('/om2/data/public/GigaSpeech/data/XL.csv', sep='\t')

# %%
ddf.head(4)
# Out:
#              wav_filename  wav_len  \
# 0  POD0000000001_S0000008     8520
# 1  POD0000000001_S0000010    12759
# 2  POD0000000001_S0000011    19980
# 3  POD0000000001_S0000012     3180
#
#                                           transcript        speaker
# 0  DOUGLAS MCGRAY IS GOING TO BE OUR GUIDE YOU WA...  POD0000000001
# 1  AH ITALIAN AND AND THEN YOU HAVE A CONVERSATIO...  POD0000000001
# 2  DOUG MCGRAY IS A JOURNALIST MY NAME IS DOUGLAS...  POD0000000001
# 3  AH YOU LEAVE WITH CASH MINUS A THREE PERCENT F...  POD0000000001

# %%
ddf = ddf.set_index('wav_filename')

# %%
ddf.head(3)
# Out:
# KeyboardInterrupt

# %%
np_tst = np.arange(8e6)

lst_ts = [{str(ix):ix} for ix in np_tst]

# %%
lst_ts[0]
# Out:
# {'0.0': 0.0}

# %%
# %%timeit

for i in range(int(100000)):
    df.iloc[i]
# Out:
# 7.52 s ± 14.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit

for i in range(int(100000)):
    df.iat[i,0]
# Out:
# 1.13 s ± 6.73 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
ddf.loc['POD0000000001_S0000008'].transcript
# Out:
# Dask Series Structure:
# npartitions=1
# POD0000000001_S0000008    object
# POD0000000001_S0000008       ...
# Name: transcript, dtype: object
# Dask Name: getitem, 228 tasks

# %%
# %%timeit

for i in range(int(100000)):
    ddf.loc['POD0000000001_S0000008']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [22], in <module>
# ----> 1 get_ipython().run_cell_magic('timeit', '', "\nfor i in range(int(100000)):\n    ddf.loc['POD0000000001_S0000008']\n")
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/pytorch_ASR/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2257, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2255 with self.builtin_trap:
#    2256     args = (magic_arg_s, cell)
# -> 2257     result = fn(*args, **kwargs)
#    2258 return result
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/pytorch_ASR/lib/python3.9/site-packages/IPython/core/magics/execution.py:1162, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1160 for index in range(0, 10):
#    1161     number = 10 ** index
# -> 1162     time_number = timer.timeit(number)
#    1163     if time_number >= 0.2:
#    1164         break
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/pytorch_ASR/lib/python3.9/site-packages/IPython/core/magics/execution.py:156, in Timer.timeit(self, number)
#     154 gc.disable()
#     155 try:
# --> 156     timing = self.inner(it, self.timer)
#     157 finally:
#     158     if gcold:
#
# File <magic-timeit>:2, in inner(_it, _timer)
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/pytorch_ASR/lib/python3.9/site-packages/dask/dataframe/indexing.py:99, in _LocIndexer.__getitem__(self, key)
#      97     iindexer = key
#      98     cindexer = None
# ---> 99 return self._loc(iindexer, cindexer)
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/pytorch_ASR/lib/python3.9/site-packages/dask/dataframe/indexing.py:130, in _LocIndexer._loc(self, iindexer, cindexer)
#     127     iindexer = slice(iindexer, iindexer)
#     129 meta = self._make_meta(iindexer, cindexer)
# --> 130 return self.obj.map_partitions(
#     131     methods.try_loc, iindexer, cindexer, meta=meta
#     132 )
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/pytorch_ASR/lib/python3.9/site-packages/dask/dataframe/core.py:713, in _Frame.map_partitions(self, func, *args, **kwargs)
#     615 @insert_meta_param_description(pad=12)
#     616 def map_partitions(self, func, *args, **kwargs):
#     617     """Apply Python function on each DataFrame partition.
#     618
#     619     Note that the index and divisions are assumed to remain unchanged.
#    (...)
#     711     None as the division.
#     712     """
# --> 713     return map_partitions(func, self, *args, **kwargs)
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/pytorch_ASR/lib/python3.9/site-packages/dask/dataframe/core.py:5941, in map_partitions(func, meta, enforce_metadata, transform_divisions, *args, **kwargs)
#    5931         dsk[k] = (
#    5932             SubgraphCallable(
#    5933                 dsk=subgraph_dsk,
#    (...)
#    5937             ),
#    5938         ) + v[1:]
#    5940 graph = HighLevelGraph.from_collections(name, dsk, dependencies=dependencies)
# -> 5941 return new_dd_object(graph, name, meta, divisions)
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/pytorch_ASR/lib/python3.9/site-packages/dask/dataframe/core.py:6988, in new_dd_object(dsk, name, meta, divisions, parent_meta)
#    6983 """Generic constructor for dask.dataframe objects.
#    6984
#    6985 Decides the appropriate output class based on the type of `meta` provided.
#    6986 """
#    6987 if has_parallel_type(meta):
# -> 6988     return get_parallel_type(meta)(dsk, name, meta, divisions)
#    6989 elif is_arraylike(meta) and meta.shape:
#    6990     import dask.array as da
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/pytorch_ASR/lib/python3.9/site-packages/dask/dataframe/core.py:3960, in DataFrame.__init__(self, dsk, name, meta, divisions)
#    3953 super().__init__(dsk, name, meta, divisions)
#    3954 if self.dask.layers[name].collection_annotations is None:
#    3955     self.dask.layers[name].collection_annotations = {
#    3956         "npartitions": self.npartitions,
#    3957         "columns": [col for col in self.columns],
#    3958         "type": typename(type(self)),
#    3959         "dataframe_type": typename(type(self._meta)),
# -> 3960         "series_dtypes": {
#    3961             col: self._meta[col].dtype
#    3962             if hasattr(self._meta[col], "dtype")
#    3963             else None
#    3964             for col in self._meta.columns
#    3965         },
#    3966     }
#    3967 else:
#    3968     self.dask.layers[name].collection_annotations.update(
#    3969         {
#    3970             "npartitions": self.npartitions,
#    (...)
#    3980         }
#    3981     )
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/pytorch_ASR/lib/python3.9/site-packages/dask/dataframe/core.py:3962, in <dictcomp>(.0)
#    3953 super().__init__(dsk, name, meta, divisions)
#    3954 if self.dask.layers[name].collection_annotations is None:
#    3955     self.dask.layers[name].collection_annotations = {
#    3956         "npartitions": self.npartitions,
#    3957         "columns": [col for col in self.columns],
#    3958         "type": typename(type(self)),
#    3959         "dataframe_type": typename(type(self._meta)),
#    3960         "series_dtypes": {
#    3961             col: self._meta[col].dtype
# -> 3962             if hasattr(self._meta[col], "dtype")
#    3963             else None
#    3964             for col in self._meta.columns
#    3965         },
#    3966     }
#    3967 else:
#    3968     self.dask.layers[name].collection_annotations.update(
#    3969         {
#    3970             "npartitions": self.npartitions,
#    (...)
#    3980         }
#    3981     )
#
# File /om4/group/mcdermott/user/imgriff/conda_envs_files/pytorch_ASR/lib/python3.9/site-packages/pandas/core/frame.py:3475, in DataFrame.__getitem__(self, key)
#    3473         if isinstance(self.columns, MultiIndex):
#    3474             return self._getitem_multilevel(key)
# -> 3475         return self._get_item_cache(key)
#    3477 # Do we have a slicer (on rows)?
#    3478 indexer = convert_to_index_sliceable(self, key)
#
# KeyboardInterrupt:

# %%
# %%timeit

for i in range(int(100000)):
    np_tst[i]
# Out:
# 20.8 ms ± 2.71 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit

for i in range(int(100000)):
    lst_ts[i][str(float(i))]
# Out:
# 76.8 ms ± 16.1 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
