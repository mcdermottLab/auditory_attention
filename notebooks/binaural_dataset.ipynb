# %%
import h5py
import numpy as np
import os
from IPython import display
from pathlib import Path

# %%
path = Path('/om/scratch/Fri/imgriff/datasets/spatial_audio_pipeline/assets/dataset_binaural_attn/v02/')

# %%
files = path.glob('train/*')

# %%
eg_filename = next(files)

# %%
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"

# %%
file = h5py.File(eg_filename, 'r', swmr=True)

# %%
batch_size = 768
index = 0
start = index * batch_size
end = start + batch_size
cut1 = start + (batch_size // 3)
cut2 = start + ((batch_size // 3) * 2)

# %%
loc_cue = file['loc_cue']
voice_cue = file['voice_cue_center_loc']
both_cue = file['voice_cue_target_loc']

# %%
cues1 = loc_cue[start:cut1].transpose((0, 2, 1))
cues2 = loc_cue[cut1:cut2].transpose((0, 2, 1))
cues3 = loc_cue[cut2:end].transpose((0, 2, 1))

# %%
cues = np.concatenate((cues1, cues2, cues3), axis=0)
cues.shape
# Out:
# (768, 2, 125000)

# %%
list_of_idx = np.random.randint(0, len(scenes), 300)

# %%
list_of_idx = np.unique(list_of_idx)

# %%
file.keys()
# Out:
# <KeysViewHDF5 ['bg_scene', 'index', 'label_loc_target_azim', 'label_loc_target_elev', 'loc_cue', 'n_sources', 'n_speech_distractors', 'snr', 'sr', 'talker_id_int', 'target', 'voice_cue_center_loc', 'voice_cue_target_loc', 'word_int']>

# %%
scenes[0]
# Out:
# array([[-0.01970245,  0.01608841],
#        [-0.01641446,  0.01813828],
#        [-0.01500773,  0.0191552 ],
#        ...,
#        [ 0.01922667,  0.00760437],
#        [ 0.01557672,  0.00692874],
#        [ 0.01286668,  0.00581439]], dtype=float32)

# %%
scenes[0].shape
# Out:
# (125000, 2)

# %%
audio = display.Audio(data=scenes[425].T, rate=50000)
audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mixed_cue_files = ['/om2/user/rphess/Auditory-Attention/config/binaural_attn/both_task_mixed_cue.yml', '/om2/user/rphess/Auditory-Attention/config/binaural_attn/word_task_mixed_cue.yml']
